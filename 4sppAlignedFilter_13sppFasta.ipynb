# %% [raw]
# # sanity check: ensure that the number of cds per parent match pre alignment values
# for ortho in aligned_fasta:
#     for sp in species_list:
#         cds_count = 0
#         parent = gff[sp][parent_groups[ortho][sp]]
#         for cds in gff[sp].children(parent, featuretype="CDS", order_by="start"):
#             cds_count += 1
#         if cds_count != len(coords[ortho][sp]):
#             print("{} {}: pre={}, post={}".format(ortho, sp, cds_count, len(coords[ortho][sp])))
#
# # sanity check: ensure n's do not exist in our cds's
# cds_w_n_count = 0
# for ortho in parent_groups:
#     for sp in species_list:
#         parent = gff[sp][parent_groups[ortho][sp]]
#         seq_list = [cds.sequence(fasta[sp]) for cds in gff[sp].children(parent, featuretype="CDS", order_by="start")]
#         if parent.strand == '-':
#             seq_list = [cds.reverse.complement for cds in seq_list[::-1]]
#         for seq in seq_list:
#             if 'n' in seq:
#                 cds_w_n_count += 1
# cds_w_n_count

# %%
import os
import gffutils
from Bio.Seq import Seq
from Bio.SeqRecord import SeqRecord
from Bio.Alphabet import IUPAC
import json
from pyfaidx import Fasta
from Bio import SeqIO
import re
from pprint import pprint as pp

# %%
import pandas
from bokeh.charts import Histogram, show
from bokeh.io import output_notebook

# %%
# globals
species_list = ["Bcur", "Bdor", "Bole", "Ccap"]
transvestigated_species_set = {'Bcor', 'Blat', 'Bzon', 'Afra', 'Bmin', 'Bjar', 'Aobl'}
gff_path = "./input/gff/"
fasta_path = "./input/fasta/"
groups_fn = "./input/groups_filtered_6181genes.txt"
output_path = "./output/"
intermediate_path = "./intermediate/"
aligned_fasta_path = "./input/aligned_4spp_fasta/"

# gap filter parameters
max_gap_percent = 0
max_gap_length = 0
# cds length filter parameters
min_cds_length = 400
max_cds_length = 600

# %%
# create handles for all .db files in intermediate directory
gff_fn = {name.split('.gff.db')[0]: intermediate_path + name for name in os.listdir(intermediate_path) if ".gff.db" in name}
gff = {key: gffutils.FeatureDB(value) for key, value in gff_fn.items()}

# create handles for all .fasta files in fasta directory
fasta_fn = {name.split('.nt.fasta')[0]: fasta_path + name for name in os.listdir(fasta_path) if
         ((".nt.fasta" in name) and (".nt.fasta.fai" not in name))}
fasta = {key: Fasta(value) for key, value in fasta_fn.items()}
'''fasta = {}
for sp,path in fasta_fn.items():
    if sp in transvestigated_species_set:
        fasta[sp] = Fasta(path, key_function = lambda x: x.split('|m.')[0])
    else:
        fasta[sp] = Fasta(path)'''
        
# import ortholog groups
with open(intermediate_path + "groups.json", 'r') as f:
    parent_groups = json.load(f)

# create handles for all .fasta files in aligned_4spp_fasta directory
aligned_fasta_fn = {name.split('.fasta')[0]: aligned_fasta_path + name for name in os.listdir(aligned_fasta_path) if
         ((".fasta.aln" in name) and (".fasta.aln.fai" not in name))}

# %%
# define functions to parse coordinates of cds's from concatinated aligned fasta w/ n's and -'s
nnn = 50
def findBreakpoints(seq):
    breakpoints = []
    loc = 0
    regex = re.compile(r"n+[-+n+]*")
    while(True):
        #loc = seq.find(nnn, loc)
        match = regex.search(seq, loc)
        if not match:
            break
        if len(match.group().replace('-', '')) >= nnn:
            breakpoints.append(match.span())
        loc = match.end()
    return(breakpoints)

def findExonCoords(seq):
    breakpoints = findBreakpoints(seq)
    length = len(seq)

    if len(breakpoints) == 0:
        return([(0, length)])

    if len(breakpoints) == 1:
        bp = breakpoints[0]
        return([(0, bp[0]), (bp[1], length)])

    elif len(breakpoints) > 0:
        exonCoords = []
        exonCoords.append((0, breakpoints[0][0])) # first exon

        for i in range(len(breakpoints) + 1)[1:-1]: # all intermediate exons
            ex_start = breakpoints[i-1][1]
            ex_end = breakpoints[i][0]
            exonCoords.append((ex_start, ex_end))

        exonCoords.append((breakpoints[-1][1], length)) # last exon
        return(exonCoords)
    
def gapPercent(seq):
    seq = str(seq)
    gappedLen = len(seq)
    gapCount = seq.count('-')
    return( (100.0*gapCount)/gappedLen )

def longestGap(seq):
    seq = str(seq)
    gap_regex = re.compile(r"-+")
    gap_list = gap_regex.findall(seq)
    if gap_list:
        return(sorted([len(gap) for gap in gap_list], reverse=True)[0])
    else:
        return(0)

# %%
# read and parse fasta files for each species
aligned_fasta = {}
for ortho in aligned_fasta_fn.keys():
    aligned_fasta[ortho] = {seq_record.id : seq_record 
                                      for seq_record in SeqIO.parse(aligned_fasta_fn[ortho],
                                                                    "fasta", alphabet=IUPAC.ambiguous_dna)}

# %%
# parse coords from aligned fasta's
coords = {} # coords[ortho][sp] = [coord, ]
for ortho in aligned_fasta:
    coords[ortho] = {}
    for sp in species_list:
        coords[ortho][sp] = findExonCoords(str(aligned_fasta[ortho][sp].seq))

# %%
# Filter aligned exons
ortho_coords = {}
coord_index_dict = {}
for ortho in coords:
    ortho_coords[ortho] = {}
    coord_index_dict[ortho] = {}
    for sp in species_list:
        for i in range(len(coords[ortho][sp])):
            coord = coords[ortho][sp][i]

            # filter for length
            start, end = coord
            length = end - start
            if not min_cds_length <= length <= max_cds_length:
                continue
                
            # filter for gap percent
            seq = str(aligned_fasta[ortho][sp].seq[start:end])
            if gapPercent(seq) > max_gap_percent:
                continue
                
            # filter for gap length
            if longestGap(seq) > max_gap_length:
                continue

            # populate coord_index_dict so I can find unique identifing info with ortho,sp,coord later
            if coord not in coord_index_dict[ortho].keys():
                coord_index_dict[ortho][coord] = {}
            coord_index_dict[ortho][coord][sp] = i
            
            # prep to filter for species membership of ortho
            if coord not in ortho_coords[ortho].keys():
                ortho_coords[ortho][coord] = set()
            ortho_coords[ortho][coord].add(sp)

# set of coords per ortho which were represented in all species
universal_ortho_coords = {}
for ortho in ortho_coords:
    for coord in ortho_coords[ortho]:
        sp_set = ortho_coords[ortho][coord]
        if len(sp_set) == len(species_list):
            if ortho not in universal_ortho_coords.keys():
                universal_ortho_coords[ortho] = set()
            universal_ortho_coords[ortho].add(coord)

# %%
data = []
for ortho in sorted(universal_ortho_coords.keys()):
    for coord in sorted(universal_ortho_coords[ortho]):
        start, end = coord
        length = end - start
        data.append((ortho, coord, length))

df = pandas.DataFrame.from_records(data=data, columns=['ortho', 'coord', 'Aligned CDS Length'])
print("from {} orthologs".format(len({x[0] for x in data})))
print(df.describe())

output_notebook()
hist = Histogram(df, values="Aligned CDS Length", title="Aligned CDS Length Histogram")
show(hist)
# Out:
# from 1535 orthologs
#        Aligned CDS Length
# count          1837.00000
# mean            489.43767
# std              58.16155
# min             400.00000
# 25%             437.00000
# 50%             484.00000
# 75%             539.00000
# max             600.00000
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="2ec68233-9dc6-41c0-b2c8-13bb567a056f">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="plotdiv" id="6e26398c-a92c-4c49-ad88-0e7a8e8ed75f"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#6e26398c-a92c-4c49-ad88-0e7a8e8ed75f").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("6e26398c-a92c-4c49-ad88-0e7a8e8ed75f");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '6e26398c-a92c-4c49-ad88-0e7a8e8ed75f' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"482a0e50-c1d0-4c7d-9ea2-d6bf911fe7cd":{"roots":{"references":[{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"bc4fbd13-09cd-4ae5-9f72-a3fe4c0efecf","type":"Rect"},{"attributes":{"location":"top_left","plot":{"id":"7d2d7939-ca55-49ca-8670-50d2d919ddf3","subtype":"Chart","type":"Plot"}},"id":"e5810193-cfe5-4700-a127-02a8f463ebd2","type":"Legend"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"c6a8b21a-af14-4fc8-a579-cd55ef051b0c","type":"Rect"},{"attributes":{"callback":null,"column_names":["width","line_alpha","y","x","height","color","fill_alpha","line_color","label"],"data":{"chart_index":["[400.0, 415.4]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[191.0],"label":["[400.0, 415.4]"],"line_alpha":[1.0],"line_color":["black"],"width":[15.384615384615358],"x":["407.7"],"y":[95.5]}},"id":"02a0377b-b457-4700-a6d4-7ca9ad0c80d8","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"02a0377b-b457-4700-a6d4-7ca9ad0c80d8","type":"ColumnDataSource"},"glyph":{"id":"614dde77-d69c-45aa-8eff-b2764ca870ce","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"e8666b26-f564-45b6-bf2d-b7bb3e7f9d2e","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"7d2d7939-ca55-49ca-8670-50d2d919ddf3","subtype":"Chart","type":"Plot"}},"id":"1ea401e9-26ed-4cbe-8ed4-11e25ce0acf0","type":"HelpTool"},{"attributes":{"callback":null,"end":210.10000000000002},"id":"99cf1ab8-8250-4bdb-9fbf-2d5db1d14414","type":"Range1d"},{"attributes":{"plot":{"id":"7d2d7939-ca55-49ca-8670-50d2d919ddf3","subtype":"Chart","type":"Plot"}},"id":"883c8aa9-28c3-46b9-9bf5-1d4f01656834","type":"PanTool"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"b1ecd0ab-edb6-4c75-9cd0-2b0ca99ed18c","type":"Rect"},{"attributes":{},"id":"63d625d0-ad0e-48ec-9858-95c7dae72ef0","type":"ToolEvents"},{"attributes":{"plot":{"id":"7d2d7939-ca55-49ca-8670-50d2d919ddf3","subtype":"Chart","type":"Plot"}},"id":"9ff55d95-8e6d-4e86-ad8f-5cfc2971a88e","type":"ResetTool"},{"attributes":{"data_source":{"id":"bf224011-a36f-4160-a606-b7cbc34594b6","type":"ColumnDataSource"},"glyph":{"id":"968f83ed-0472-4605-899f-d25fee97cfc2","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"45bc5c65-e41e-414e-9127-48866602325e","type":"GlyphRenderer"},{"attributes":{"below":[{"id":"b016e4be-a859-428f-a116-a3a4be4147d7","type":"LinearAxis"}],"left":[{"id":"599b900e-4063-4db0-9975-21072f278efd","type":"LinearAxis"}],"renderers":[{"id":"ba011395-ee05-458d-aa4c-ea317edf9b77","type":"BoxAnnotation"},{"id":"e8666b26-f564-45b6-bf2d-b7bb3e7f9d2e","type":"GlyphRenderer"},{"id":"6421aa1e-3847-46d9-a0a6-2b372f61e488","type":"GlyphRenderer"},{"id":"056db81f-a915-409d-96d1-4238a29335ac","type":"GlyphRenderer"},{"id":"dc2cbcd3-bb53-400b-9e9f-53690e93ddaf","type":"GlyphRenderer"},{"id":"51f8ccff-4969-42c2-9ecc-3473063a7db6","type":"GlyphRenderer"},{"id":"723df03a-c857-4848-99a7-d2a793ff7b4a","type":"GlyphRenderer"},{"id":"ebc92cfc-0688-4b31-a4a9-c7ce4a86afe9","type":"GlyphRenderer"},{"id":"14b366b2-b2e6-4358-ab77-9094a70a5de0","type":"GlyphRenderer"},{"id":"c0b22724-bad4-4e0a-9ce1-2efd0b95f36f","type":"GlyphRenderer"},{"id":"6aed42f7-0d83-4c7a-adb4-79b0578e23a1","type":"GlyphRenderer"},{"id":"45bc5c65-e41e-414e-9127-48866602325e","type":"GlyphRenderer"},{"id":"7b13c780-7d87-4548-b66d-bfdecfa8b224","type":"GlyphRenderer"},{"id":"175e8447-0e08-4cff-a6 ...

# %%
data = [(ortho, len(universal_ortho_coords[ortho])) for ortho in universal_ortho_coords]
                
df = pandas.DataFrame.from_records(data=data, columns=['ortho', 'exons per ortho'])
print(df.describe())

output_notebook()
hist = Histogram(df, values="exons per ortho", title="exons per ortho Histogram")
show(hist)
# Out:
#        exons per ortho
# count      1535.000000
# mean          1.196743
# std           0.483485
# min           1.000000
# 25%           1.000000
# 50%           1.000000
# 75%           1.000000
# max           4.000000
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="b0078891-b1aa-4da1-b364-16e2b548753d">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="plotdiv" id="66723f7e-046f-44f6-9d27-6ffdf7ab771a"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#66723f7e-046f-44f6-9d27-6ffdf7ab771a").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("66723f7e-046f-44f6-9d27-6ffdf7ab771a");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '66723f7e-046f-44f6-9d27-6ffdf7ab771a' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"eff1c55d-6486-418f-bdf3-ccd9e186a0d9":{"roots":{"references":[{"attributes":{},"id":"63d3692e-900b-4d52-992c-f68d2ab7b67d","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"d1966804-74b6-41ec-9442-ddc5880addac","subtype":"Chart","type":"Plot"}},"id":"a1ad92a5-6680-459a-b034-df519065b693","type":"WheelZoomTool"},{"attributes":{"axis_label":"Count( Exons Per Ortho )","formatter":{"id":"63d3692e-900b-4d52-992c-f68d2ab7b67d","type":"BasicTickFormatter"},"plot":{"id":"d1966804-74b6-41ec-9442-ddc5880addac","subtype":"Chart","type":"Plot"},"ticker":{"id":"b19e7419-7290-4c7c-b9a9-d07a72d26b6d","type":"BasicTicker"}},"id":"da67e0c0-d3e8-4bf2-bfb1-16dba9ea63c3","type":"LinearAxis"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"686886ac-7920-436d-92e5-0774fb6a6fd5","type":"PanTool"},{"id":"a1ad92a5-6680-459a-b034-df519065b693","type":"WheelZoomTool"},{"id":"0a358a7e-8202-4a20-9c13-8146a5ff7526","type":"BoxZoomTool"},{"id":"b42b12d5-a593-438a-97ab-0d8edceacf4f","type":"SaveTool"},{"id":"967b4c5c-b4b5-479c-94d3-8415f54453f0","type":"ResetTool"},{"id":"c49dc60b-2f29-4228-b694-81eb3c04c69d","type":"HelpTool"}]},"id":"916486b4-80d7-490a-baef-ed6fc3cb7b66","type":"Toolbar"},{"attributes":{"callback":null,"end":1412.4},"id":"8b2ba2bb-7706-4bb4-9ef8-f29239b6d51e","type":"Range1d"},{"attributes":{"callback":null,"end":4.125,"start":0.875},"id":"5a31863a-4dd5-4dc0-b819-133259ba8ec9","type":"Range1d"},{"attributes":{"plot":{"id":"d1966804-74b6-41ec-9442-ddc5880addac","subtype":"Chart","type":"Plot"}},"id":"967b4c5c-b4b5-479c-94d3-8415f54453f0","type":"ResetTool"},{"attributes":{},"id":"b19e7419-7290-4c7c-b9a9-d07a72d26b6d","type":"BasicTicker"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"0bc54598-731a-481d-90d3-65104ec9c608","type":"Rect"},{"attributes":{"axis_label":"exons per ortho","formatter":{"id":"b28bbaac-5f9e-492d-88ce-0b0a1f051851","type":"BasicTickFormatter"},"plot":{"id":"d1966804-74b6-41ec-9442-ddc5880addac","subtype":"Chart","type":"Plot"},"ticker":{"id":"ee683c34-1884-4a7c-96c1-d2c1762e8047","type":"BasicTicker"}},"id":"2d56a8fa-2eaa-4e91-9c09-a3572945a664","type":"LinearAxis"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"709ecc8b-0c97-4450-a357-52b39daf4069","type":"Rect"},{"attributes":{"plot":{"id":"d1966804-74b6-41ec-9442-ddc5880addac","subtype":"Chart","type":"Plot"}},"id":"686886ac-7920-436d-92e5-0774fb6a6fd5","type":"PanTool"},{"attributes":{"callback":null,"column_names":["width","line_alpha","y","x","height","color","fill_alpha","line_color","label"],"data":{"chart_index":["(2.0, 3.0]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[207.0],"label":["(2.0, 3.0]"],"line_alpha":[1.0],"line_color":["black"],"width":[1.0],"x":["2.5"],"y":[103.5]}},"id":"ad81a0ae-d9ee-42db-832d-7ddabd6cca17","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"410fb531-2b87-43f8-8d70-1b0233280346","type":"ColumnDataSource"},"glyph":{"id":"195d48bb-9ba0-48f6-9399-91071e7b0cc0","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"09803f7e-bd55-4c5a-8563-e8fcde7b611f","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"7b2a0112-c717-4288-8ebb-9fb9c0f9039b","type":"ColumnDataSource"},"glyph":{"id":"0bc54598-731a-481d-90d3-65104ec9c608","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"ccbbbe2f-baa5-4e53-9945-cd966b3e1f68","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"d1966804-74b6-41ec-9442-ddc5880addac","subtype":"Chart","type":"Plot"}},"id":"b42b12d5-a593-438a-97ab-0d8e ...

# %%
fasta_prep = {}
for ortho in universal_ortho_coords:
    fasta_prep[ortho] = {}
    cds_list = {}
    for coord in universal_ortho_coords[ortho]:
        fasta_prep[ortho][coord] = {}
        for sp in species_list:
            if sp not in cds_list.keys():
                parent = gff[sp][parent_groups[ortho][sp]]
                cds_list[sp] = [cds for cds in gff[sp].children(parent, featuretype="CDS", order_by="start")]

            index = coord_index_dict[ortho][coord][sp]
            cds = cds_list[sp][index]
            fasta_prep[ortho][coord][sp] = cds

# %%
nnn = Seq("nnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnn", IUPAC.ambiguous_dna)
for ortho in fasta_prep:
    for coord in fasta_prep[ortho]:
        with open(output_path + ortho + "_" + str(coord[0]) + "-" + str(coord[1]) + ".13spp.fasta", "w") as f:
            for sp in species_list:
                cds = fasta_prep[ortho][coord][sp]
                start,end = coord
                seq = nnn + aligned_fasta[ortho][sp].seq[start:end] + nnn
                seqReq = SeqRecord(seq, id=sp, description=cds.id)
                f.write(seqReq.format("fasta"))
                
            for sp in sorted(parent_groups[ortho]):
                if sp in species_list:
                    continue
                parent = gff[sp][parent_groups[ortho][sp]]
                strand = parent.strand
                cds_list = [cds for cds in gff[sp].children(parent, featuretype="CDS", order_by="start")]
                cat_seq = Seq("", IUPAC.ambiguous_dna)
                for cds in cds_list:
                    if sp in transvestigated_species_set:
                        seq = Seq(str(fasta[sp][parent_groups[ortho][sp]]), IUPAC.ambiguous_dna)
                        cds_len = cds.end - cds.start
                        if cds_len + 1 == len(seq):
                            cat_seq += seq
                        else:
                            print("{} {} {} {} {}".format(ortho, sp, coord, cds_len, len(seq)))
                    else:
                        cat_seq += Seq(str(cds.sequence(fasta=fasta[sp], use_strand=False)), IUPAC.ambiguous_dna)
                            
                    #cat_seq += Seq(fasta[sp][cds.chrom][cds.start:cds.end].seq, IUPAC.ambiguous_dna)
                if strand == '-':
                    cat_seq = cat_seq.reverse_complement()
                seqReq = SeqRecord(cat_seq, id=sp, description=parent.id)
                f.write(seqReq.format("fasta"))
