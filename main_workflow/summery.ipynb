# %%
import pandas as pd
from bokeh.charts import Scatter, Histogram, output_notebook, output_file, show
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="6d595285-9069-4ac4-bb78-b50827942ac1">Loading BokehJS ...</span>
#     </div>

# %%
df = pd.read_csv("combined_summory.csv")
df.rename(columns=lambda x: x.split('(')[0], inplace=True)
df.index = df[["CDS_Ortholog","PRIMER_LEFT_0_SEQUENCE","PRIMER_RIGHT_0_SEQUENCE"]]

# %%
df.count()
# Out:
# CDS_Ortholog               49218
# Primer_Version             49218
# Ambiguities_Allowed        49218
# Total_Ambiguities          49218
# Left_Ambiguities           49218
# Right_Ambiguities          49218
# Max_Ambiguities            49218
# Total_Combinations         49218
# Left_Combinations          49218
# Right_Combinations         49218
# PI_Score                   49218
# Target_Sequence_Length     49218
# PRIMER_LEFT_0_SEQUENCE     49218
# PRIMER_RIGHT_0_SEQUENCE    49218
# PRIMER_LEFT_0_TM           49218
# PRIMER_RIGHT_0_TM          49218
# Species_List               49218
# dtype: int64

# %%
df.sort_values(by=["Ambiguities_Allowed","Primer_Version"], inplace=True)
df.drop_duplicates(subset=["CDS_Ortholog","PRIMER_LEFT_0_SEQUENCE","PRIMER_RIGHT_0_SEQUENCE"], keep="first", inplace=True)

# %%
df.count()
# Out:
# CDS_Ortholog               43985
# Primer_Version             43985
# Ambiguities_Allowed        43985
# Total_Ambiguities          43985
# Left_Ambiguities           43985
# Right_Ambiguities          43985
# Max_Ambiguities            43985
# Total_Combinations         43985
# Left_Combinations          43985
# Right_Combinations         43985
# PI_Score                   43985
# Target_Sequence_Length     43985
# PRIMER_LEFT_0_SEQUENCE     43985
# PRIMER_RIGHT_0_SEQUENCE    43985
# PRIMER_LEFT_0_TM           43985
# PRIMER_RIGHT_0_TM          43985
# Species_List               43985
# dtype: int64

# %%
df.sort_values(by=["CDS_Ortholog","Total_Combinations","PI_Score"],ascending=[1,1,0], inplace=True)

# %%
picks_df = df.drop_duplicates(subset=["CDS_Ortholog","Total_Combinations"], keep="first")

# %%
picks_df.count()
# Out:
# CDS_Ortholog               14589
# Primer_Version             14589
# Ambiguities_Allowed        14589
# Total_Ambiguities          14589
# Left_Ambiguities           14589
# Right_Ambiguities          14589
# Max_Ambiguities            14589
# Total_Combinations         14589
# Left_Combinations          14589
# Right_Combinations         14589
# PI_Score                   14589
# Target_Sequence_Length     14589
# PRIMER_LEFT_0_SEQUENCE     14589
# PRIMER_RIGHT_0_SEQUENCE    14589
# PRIMER_LEFT_0_TM           14589
# PRIMER_RIGHT_0_TM          14589
# Species_List               14589
# dtype: int64

# %%
tooltips=[
    ('CDS_Ortholog', '@CDS_Ortholog'),
    ('Ambiguities_Allowed', '@Ambiguities_Allowed'),
    ('Primer_Version', '@Primer_Version'),
    ('PI_Score', '@PI_Score'),
    ('Target_Sequence_Length', '@Target_Sequence_Length'),
    ('Total_Combinations', '@Total_Combinations'),
    ('PRIMER_LEFT_0_SEQUENCE', '@PRIMER_LEFT_0_SEQUENCE'),
    ('PRIMER_LEFT_0_TM', '@PRIMER_LEFT_0_TM'),
    ('PRIMER_RIGHT_0_SEQUENCE', '@PRIMER_RIGHT_0_SEQUENCE'),
    ('PRIMER_RIGHT_0_TM', '@PRIMER_RIGHT_0_TM')
]


p = Scatter(picks_df, x='Target_Sequence_Length', y='PI_Score', color="Max_Ambiguities", tooltips=tooltips,
           title="Score vs Insert_Length Colored by Max_Ambiguities")

hl = Histogram(picks_df, values="Target_Sequence_Length", title="Insert_Length Distribution Colored by Max_Ambiguities", color="Max_Ambiguities", bins=30, legend="top_right")

hs = Histogram(picks_df, values='PI_Score', title="Score Distribution Colored by Max_Ambiguities", color="Max_Ambiguities", bins=14, legend="top_right")

show(p)
show(hl)
show(hs)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="79c7f0cf-19d7-4d88-b4d4-40b7ac578b8e"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
# ...
