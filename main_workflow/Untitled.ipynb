# %%
#!/usr/bin/env python

# coding: utf-8

# In[1]:

import csv
from collections import Counter
from config import expand_iupac
from operator import mul
from functools import reduce

possibilities = {key:len(value) for key,value in expand_iupac.items()}

fn = ["../output{}/summory.csv".format(i) for i in range(3)]


header = ('CDS_Ortholog',
 'Primer_Version',
 'Ambiguities_Allowed(p3_input)',
 'Total_Ambiguities(L+R)',
 'Left_Ambiguities',
 'Right_Ambiguities',
 'Max_Ambiguities(L|R)',
 'Total_Combinations(L+R)',
 'Left_Combinations',
 'Right_Combinations',
 'PI_Score',
 'Target_Sequence_Length',
 'PRIMER_LEFT_0_SEQUENCE',
 'PRIMER_RIGHT_0_SEQUENCE',
 'PRIMER_LEFT_0_TM',
 'PRIMER_RIGHT_0_TM')

def amb_count(seq):
    return sum([value for key,value in Counter(seq).items() if key in "yrwskmdvhbn-"])

def amb_combinations(seq):
    return reduce(mul, [possibilities[nuc.upper()] for nuc in seq])

# %%
data = []
for i in range(len(fn)):
    with open(fn[i]) as f:
        lines = f.readlines()
        lines = [line.strip().split(",") for line in lines[1:]]
        lines = {line[0]:(line[0][:-3],
                          int(line[0][-1:]),
                          i,
                          amb_count(line[5] + line[6]),
                          amb_count(line[5]),
                          amb_count(line[6]),
                          max(amb_count(line[5]), amb_count(line[6])),
                          amb_combinations(line[5]) + amb_combinations(line[6]),
                          amb_combinations(line[5]),
                          amb_combinations(line[6]),
                          float(line[1]),
                          int(line[4]),
                          line[5],
                          line[6],
                          float(line[7]),
                          float(line[8])) for line in lines}

        data = data + [rec for rec in lines.values()]


data = sorted(data, key=lambda x: x[0])

# %%
data
# Out:
# [('orth10028_686-1116',
#   0,
#   2,
#   4,
#   2,
#   2,
#   2,
#   8,
#   4,
#   4,
#   1.6922946315434662,
#   165,
#   'TGCArGTGTGGCGyTTCCTC',
#   'GCGCCsACCAArTACACCTC',
#   55.915,
#   55.151),
#  ('orth10028_686-1116',
#   3,
#   2,
#   4,
#   2,
#   2,
#   2,
#   8,
#   4,
#   4,
#   1.6805633141141438,
#   163,
#   'CArGTGTGGCGyTTCCTCTC',
#   'GCGCCsACCAArTACACCTC',
#   53.649,
#   55.151),
#  ('orth10028_686-1116',
#   2,
#   2,
#   4,
#   2,
#   2,
#   2,
#   8,
#   4,
#   4,
#   1.6805633141141438,
#   163,
#   'GCArGTGTGGCGyTTCCTCTC',
#   'GCGCCsACCAArTACACCTC',
#   56.835,
#   55.151),
#  ('orth10028_686-1116',
#   4,
#   2,
#   4,
#   2,
#   2,
#   2,
#   8,
#   4,
#   4,
#   1.6846691208948192,
#   164,
#   'TGCArGTGTGGCGyTTCCTCT',
#   'GCGCCsACCAArTACACCTC',
#   57.422,
#   55.151),
#  ('orth10028_686-1116',
#   1,
#   2,
#   4,
#   2,
#   2,
#   2,
#   8,
#   4,
#   4,
#   1.6846691208948192,
#   164,
#   'GCArGTGTGGCGyTTCCTCT',
#   'GCGCCsACCAArTACACCTC',
#   55.619,
#   55.151),
#  ('orth10136_1834-2121',
#   1,
#   1,
#   2,
#   1,
#   1,
#   1,
#   4,
#   2,
#   2,
#   1.2897273882040707,
#   170,
#   'CGyTGTCCCATCTGTGACAA',
#   'TATGGTGCGyTGTCGGAAGA',
#   54.875,
#   56.132),
#  ('orth10136_1834-2121',
#   2,
#   1,
#   2,
#   1,
#   1,
#   1,
#   4,
#   2,
#   2,
#   1.285925876045718,
#   169,
#   'CGyTGTCCCATCTGTGACAAG',
#   'TATGGTGCGyTGTCGGAAGA',
#   56.135,
#   56.132),
#  ('orth10136_1834-2121',
#   4,
#   1,
#   2,
#   1,
#   1,
#   1,
#   4,
#   2,
#   2,
#   1.2823342067159846,
#   168,
#   'GyTGTCCCATCTGTGACAAGG',
#   'TATGGTGCGyTGTCGGAAGA',
#   55.736,
#   56.132),
#  ('orth10136_1834-2121',
#   3,
#   1,
#   2,
#   1,
#   1,
#   1,
#   4,
#   2,
#   2,
#   1.285925876045718,
#   169,
#   'yTGTCCCATCTGTGACAAG',
#   'TATGGTGCGyTGTCGGAAGA',
#   55.8,
#   56.132),
#  ('orth10136_1834-2121',
#   0,
#   1,
#   2,
#   1,
#   1,
#   1,
#   4,
#   2,
#   2,
#   1.2635918624897706,
#   166,
#   'TCCCATCTGTGACAAGGAr',
#   'TATGGTGCGyTGTCGGAAGA',
#   55.939,
#   56.132),
#  ('orth10136_1834-2121',
#   1,
#   2,
#   3,
#   1,
#   2,
#   2,
#   6,
#   2,
#   4,
#   1.2354344288863197,
#   162,
#   'TCCCATCTGTGACAAGGAr',
#   'GTGCGyTGTCGGAAGAAmCG',
#   55.939,
#   55.842),
#  ('orth10136_1834-2121',
#   4,
#   2,
#   3,
#   1,
#   2,
#   2,
#   6,
#   2,
#   4,
#   1.262802739829297,
#   166,
#   'CGyTGTCCCATCTGTGACAA',
#   'GTGCGyTGTCGGAAGAAmCG',
#   54.875,
#   55.842),
#  ('orth10136_1834-2121',
#   3,
#   2,
#   2,
#   1,
#   1,
#   1,
#   4,
#   2,
#   2,
#   1.285925876045718,
#   169,
#   'CGyTGTCCCATCTGTGACAAG',
#   'TATGGTGCGyTGTCGGAAGA',
#   56.135,
#   56.132),
#  ('orth10136_1834-2121',
#   2,
#   2,
#   2,
#   1,
#   1,
#   1,
#   4,
#   2,
#   2,
#   1.2897273882040707,
#   170,
#   'CGyTGTCCCATCTGTGACAA',
#   'TATGGTGCGyTGTCGGAAGA',
#   54.875,
#   56.132),
#  ('orth10136_1834-2121',
#   0,
#   2,
#   2,
#   1,
#   1,
#   1,
#   4,
#   2,
#   2,
#   1.2635918624897706,
#   166,
#   'TCCCATCTGTGACAAGGAr',
#   'TATGGTGCGyTGTCGGAAGA',
#   55.939,
#   56.132),
#  ('orth10223_1982-2252',
#   0,
#   2,
#   4,
#   2,
#   2,
#   2,
#   12,
#   8,
#   4,
#   1.0679110232740965,
#   169,
#   'CTnATGAACATmATACGCGT',
#   'TGAAATGAGGTTArrAAATGCGT',
#   53.81,
#   55.308),
#  ('orth10223_1982-2252',
#   2,
#   2,
#   4,
#   2,
#   2,
#   2,
#   12,
#   8,
#   4,
#   1.0655384867007984,
#   170,
#   'CTnATGAACATmATACGCGT',
#   'TGAAATGAGGTTArrAAATGCG',
#   53.81,
#   53.565),
#  ('orth10223_1982-2252',
#   3,
#   2,
#   4,
#   2,
#   2,
#   2,
#   12,
#   8,
#   4,
#   1.0679110232740965,
#   169,
#   'CTnATGAACATmATACGCGT',
#   'GAAATGAGGTTArrAAATGCGT',
#   53.81,
#   53.561),
#  ('orth10223_1982-2252',
#   4,
#   2,
#   4,
#   2,
#   2,
#   2,
#   12,
#   8,
#   4,
#   1.0655384867007984,
#   170,
#   'nATGAACATmATACGCGT',
#   'TGAAATGAGGTTArrAAATGCG',
#   55.578,
#   53.565),
#  ('orth10223_1982-2252',
#   1,
#   2,
#   4,
#   2,
#   2,
#   2,
#   12,
#   8,
#   4,
#   1.0679110232740965,
#   169,
#   'nATGAACATmATACGCGT',
#   'TGAAATGAGGTTArrAAATGCGT',
#   55.578,
#   55.308),
#  ('orth10262_1395-1632',
#   0,
#   2,
#   4,
#   2,
#   2,
#   2,
#   10,
#   4,
#   6,
#   1.2398696894570795,
#   155,
#   'AGTCCACyGGCATGACrACACA',
#   'GCATAyTCvGCCTTCACATCATCCA',
#   55.263,
#   55.189),
#  ('orth10262_1395-1632',
#   4,
#   2,
#   4,
#   2,
#   2,
#   2,
#   10,
#   4,
#   6,
#   1.2398696894570795,
#   155,
#   'GAGTCCACyGGCATGACrACACA',
#   'GCATAyTCvGCCTTCACATCATCCA',
#   56.419,
#   55.189),
#  ('orth10262_1395-1632',
#   3,
#   2,
#   4,
#   2,
#   2,
#   2,
#   10,
#   4,
#   6,
#   1.23757945177565,
#   156,
#   'AGTCCACyGGCATGACrACACA',
#   'GCATAyTCvGCCTTCACATCATCC',
#   55.263,
#   53.611),
#  ('orth10262_1395-1632',
#   2,
#   2,
#   4,
#   2,
#   2,
#   2,
#   10,
#   4,
#   6,
#   1.2398696894570795,
#   155,
#   'GTCCACyGGCATGACrACACA',
#   'GCATAyTCvGCCTTCACATCATCCA',
#   53.749,
#   55.189),
#  ('orth10262_1395-1632',
#   1,
#   2,
#   4,
#   2,
#   2,
#   2,
#   10,
#   4,
#   6,
#   1.217209461819339,
#   156,
#   'GAGTCCACyGGCATGACrACAC',
#   'GCATAyTCvGCCTTCACATCATCCA',
#   54.752,
#   55.189),
#  ('orth10262_574-1105',
#   2,
#   1,
#   2,
#   1,
#   1,
#   1,
#   5,
#   3,
#   2,
#   2.2717287754971944,
#   247,
#   'TGGTGGGTGATCGCbTATGC',
#   'GGACGCGACAATTTsGCAAA',
#   55.116,
#   55.747),
#  ('orth10262_574-1105',
#   0,
#   1,
#   1,
#   1,
#   0,
#   1,
#   4,
#   3,
#   1,
#   2.517117359694666,
#   351,
#   'TGGTGGGTGATCGCbTATGC',
#   'GACTCTTTCGCATATCACCC',
#   55.116,
#   56.024),
#  ('orth10262_574-1105',
#   4,
#   1,
#   2,
#   1,
#   1,
#   1,
#   5,
#   3,
#   2,
#   2.516734758854227,
#   304,
#   'TGGTGGGTGATCGCbTATGC',
#   'TCCCGATGrCAAATCACAGC',
#   55.116,
#   56.423),
#  ('orth10262_574-1105',
#   3,
#   1,
#   1,
#   1,
#   0,
#   1,
#   4,
#   3,
#   1,
#   2.5857760774658685,
#   349,
#   'TGGTGGGTGATCGCbTATGC',
#   'CTCTTTCGCATATCACCCAC',
#   55.116,
#   56.31),
#  ('orth10262_574-1105',
#   1,
#   1,
#   2,
#   1,
#   1,
#   1,
#   5,
#   3,
#   2,
#   2.5186384792484886,
#   308,
#   'TGGTGGGTGATCGCbTATGC',
#   'CCCATCCCGATGrCAAATCA',
#   55.116,
#   55.785),
#  ('orth10262_574-1105',
#   0,
#   2,
#   2,
#   2,
#   0,
#   2,
#   7,
#   6,
#   1,
#   1.6271210075127225,
#   249,
#   'GAGGTGCGyAGCTTTGTbTC',
#   'GACTCTTTCGCATATCACCC',
#   55.504,
#   56.024),
#  ('orth10262_574-1105',
#   4,
#   2,
#   2,
#   2,
#   0,
#   2,
#   7,
#   6,
#   1,
#   1.6268464420081132,
#   250,
#   'GGAGGTGCGyAGCTTTGTbT',
#   'GACTCTTTCGCATATCACCC',
#   56.835,
#   56.024),
#  ('orth10262_574-1105',
#   1,
#   2,
#   4,
#   2,
#   2,
#   2,
#   10,
#   6,
#   4,
#   1.3651252243277876,
#   172,
#   'GAGGTGCGyAGCTTTGTbTC',
#   'AAGAGyAAmGTTTGTGCGCG',
#   55.504,
#   55.939),
#  ('orth10262_574-1105',
#   2,
#   2,
#   3,
#   2,
#   1,
#   2,
#   8,
#   6,
#   2,
#   1.4987168450729893,
#   206,
#   'GAGGTGCGyAGCTTTGTbTC',
#   'CCCATCCCGATGrCAAATCA',
#   55.504,
#   55.785),
#  ('orth10262_574-1105',
#   3,
#   2,
#   2,
#   2,
#   0,
#   2,
#   7,
#   6,
#   1,
#   1.628010040149534,
#   247,
#   'GAGGTGCGyAGCTTTGTbTC',
#   'CTCTTTCGCATATCACCCAC',
#   55.504,
#   56.31),
#  ('orth10315_1281-1727',
#   2,
#   2,
#   3,
#   2,
#   1,
#   2,
#   6,
#   4,
#   2,
#   1.2087833762009683,
#   160,
#   'CCGATCGTGATGArATyGCC',
#   'rTGCATGGGTTTCTTCTTCA',
#   55.474,
#   56.495),
#  ('orth10315_1281-1727',
#   1,
#   2,
#   2,
#   2,
#   0,
#   2,
#   5,
#   4,
#   1,
#   1.2149859865096861,
#   160,
#   'GCCGATCGTGATGArATyGC',
#   'TGCATGGGTTTCTTCTTCAA',
#   56.145,
#   55.448),
#  ('orth10315_1281-1727',
#   0,
#   2,
#   3,
#   2,
#   1,
#   2,
#   6,
#   4,
#   2,
#   1.2121337268765848,
#   161,
#   'GCCGATCGTGATGArATyGC',
#   'rTGCATGGGTTTCTTCTTCA',
#   56.145,
#   56.495),
#  ('orth10315_1281-1727',
#   3,
#   2,
#   2,
#   2,
#   0,
#   2,
#   5,
#   4,
#   1,
#   1.2166630139156156,
#   159,
#   'GCCGATCGTGATGArATyGC',
#   'TGCATGGGTTTCTTCTTCAAT',
#   56.145,
#   56.028),
#  ('orth10315_1281-1727',
#   4,
#   2,
#   3,
#   2,
#   1,
#   2,
#   6,
#   4,
#   2,
#   1.3448560984907711,
#   171,
#   'ACCTGTCrCCmGCCGATCGTG',
#   'rTGCATGGGTTTCTTCTTCA',
#   55.38,
#   56.495),
#  ('orth10324_614-1278',
#   3,
#   2,
#   3,
#   2,
#   1,
#   2,
#   6,
#   4,
#   2,
#   1.6319257683717598,
#   171,
#   'sACACAyATGCAAGATCT',
#   'GCATGCGTCGTATCTCTTCr',
#   55.148,
#   55.596),
#  ('orth10324_614-1278',
#   1,
#   2,
#   3,
#   2,
#   1,
#   2,
#   6,
#   4,
#   2,
#   1.4004137479361083,
#   159,
#   'TGCAAGATCTrAArGACACCAC',
#   'GCATGCGTCGTATCTCTTCr',
#   55.701,
#   55.596),
#  ('orth10324_614-1278',
#   2,
#   2,
#   3,
#   2,
#   1,
#   2,
#   6,
#   4,
#   2,
#   3.211758214301394,
#   342,
#   'TCAAACArCArGATCGCGATCT',
#   'GCATGCGTCGTATCTCTTCr',
#   55.187,
#   55.596),
#  ('orth10324_614-1278',
#   4,
#   2,
#   3,
#   2,
#   1,
#   2,
#   6,
#   4,
#   2,
#   1.402596941631155,
#   160,
#   'TGCAAGATCTrAArGACACCA',
#   'GCATGCGTCGTATCTCTTCr',
#   54.142,
#   55.596),
#  ('orth10324_614-1278',
#   0,
#   2,
#   3,
#   2,
#   1,
#   2,
#   6,
#   4,
#   2,
#   1.4034946911365938,
#   158,
#   'GCAAGATCTrAArGACACCACA',
#   'GCATGCGTCGTATCTCTTCr',
#   55.701,
#   55.596),
#  ('orth10339_505-906',
#   2,
#   0,
#   0,
#   0,
#   0,
#   0,
#   2,
#   1,
#   1,
#   0.19153670876577703,
#   162,
#   'ATGTTAGCGACGGGTATG',
#   'ACCAAACTGAGCGCAACATA',
#   54.181,
#   58.109),
#  ('orth10339_505-906',
#   1,
#   0,
#   0,
#   0,
#   0,
#   0,
#   2,
#   1,
#   1,
#   0.19001358352276,
#   160,
#   'ATGTTAGCGACGGGTATGCT',
#   'ACCAAACTGAGCGCAACATA',
#   59.249,
#   58.109),
#  ('orth10339_505-906',
#   0,
#   0,
#   0,
#   0,
#   0,
#   0,
#   2,
#   1,
#   1,
#   0.18983030114055935,
#   161,
#   'ATGTTAGCGACGGGTATGC',
#   'ACCAAACTGAGCGCAACATA',
#   57.716,
#   58.109),
#  ('orth10339_505-906',
#   4,
#   0,
#   0,
#   0,
#   0,
#   0,
#   2,
#   1,
#   1,
#   0.1890347338249977,
#   163,
#   'ATGTTAGCGACGGGTATGC',
#   'ACCAAACTGAGCGCAACA',
#   57.716,
#   57.766),
#  ('orth10339_505-906',
#   3,
#   0,
#   0,
#   0,
#   0,
#   0,
#   2,
#   1,
#   1,
#   0.189379444296661,
#   162,
#   'ATGTTAGCGACGGGTATGC',
#   'ACCAAACTGAGCGCAACAT',
#   57.716,
#   58.281),
#  ('orth10339_505-906',
#   2,
#   1,
#   2,
#   1,
#   1,
#   1,
#   4,
#   2,
#   2,
#   0.1777134603529769,
#   163,
#   'TTAGCGACGGGTATGCTmTC',
#   'ATAAAsACCAAACTGAGCGC',
#   55.254,
#   55.83),
#  ('orth10339_505-906',
#   1,
#   1,
#   2,
#   1,
#   1,
#   1,
#   4,
#   2,
#   2,
#   0.17926276568442076,
#   164,
#   'GTTAGCGACGGGTATGCTmT',
#   'ATAAAsACCAAACTGAGCGC',
#   55.538,
#   55.83),
#  ('orth10339_505-906',
#   0,
#   1,
#   2,
#   1,
#   1,
#   1,
#   4,
#   2,
#   2,
#   0.18865967174318188,
#   168,
#   'TrATGTTAGCGACGGGTATG',
#   'ATAAAsACCAAACTGAGCGC',
#   56.396,
#   55.83),
#  ('orth10339_505-906',
#   4,
#   1,
#   2,
#   1,
#   1,
#   1,
#   4,
#   2,
#   2,
#   0.179422975320202,
#   163,
#   'GTTAGCGACGGGTATGCTmT',
#   'TAAAsACCAAACTGAGCGCA',
#   55.538,
#   57.155),
#  ('orth10339_505-906',
#   3,
#   1,
#   2,
#   1,
#   1,
#   1,
#   4,
#   2,
#   2,
#   0.18905368256362964,
#   167,
#   'TrATGTTAGCGACGGGTATG',
#   'TAAAsACCAAACTGAGCGCA',
#   56.396,
#   57.155),
#  ('orth10339_505-906',
#   0,
#   2,
#   2,
#   1,
#   1,
#   1,
#   4,
#   2,
#   2,
#   0.18865967174318188,
#   168,
#   'TrATGTTAGCGACGGGTATG',
#   'ATAAAsACCAAACTGAGCGC',
#   56.396,
#   55.83),
#  ('orth10339_505-906',
#   1,
#   2,
#   2,
#   1,
#   1,
#   1,
#   4,
#   2,
#   2,
#   0.17926276568442076,
#   164,
#   'GTTAGCGACGGGTATGCTmT',
#   'ATAAAsACCAAACTGAGCGC',
#   55.538,
#   55.83),
#  ('orth10339_505-906',
#   2,
#   2,
#   3,
#   2,
#   1,
#   2,
#   6,
#   4,
#   2,
#   0.1879677123101919,
#   169,
#   'yTrATGTTAGCGACGGGTAT',
#   'ATAAAsACCAAACTGAGCGC',
#   56.651,
#   55.83),
#  ('orth10339_505-906',
#   4,
#   2,
#   3,
#   2,
#   1,
#   2,
#   6,
#   4,
#   2,
#   0.1877043078537385,
#   170,
#   'yTrATGTTAGCGACGGGTA',
#   'ATAAAsACCAAACTGAGCGC',
#   56.08,
#   55.83),
#  ('orth10339_505-906',
#   3,
#   2,
#   2,
#   1,
#   1,
#   1,
#   4,
#   2,
#   2,
#   0.1777134603529769,
#   163,
#   'TTAGCGACGGGTATGCTmTC',
#   'ATAAAsACCAAACTGAGCGC',
#   55.254,
#   55.83),
#  ('orth10362_263-601',
#   1,
#   0,
#   0,
#   0,
#   0,
#   0,
#   2,
#   1,
#   1,
#   0.3775168605702069,
#   179,
#   'TCTGCGATGATGTGTCAATC',
#   'CTGGAACGTTTCGATGTCG',
#   55.949,
#   56.783),
#  ('orth10362_263-601',
#   0,
#   0,
#   0,
#   0,
#   0,
#   0,
#   2,
#   1,
#   1,
#   0.3771792770949342,
#   182,
#   'TCTGCGATGATGTGTCAATC',
#   'GAGCTGGAACGTTTCGATG',
#   55.949,
#   56.752),
#  ('orth10362_263-601',
#   2,
#   0,
#   0,
#   0,
#   0,
#   0,
#   2,
#   1,
#   1,
#   0.376132148668412,
#   183,
#   'TCTGCGATGATGTGTCAATC',
#   'TTGAGCTGGAACGTTTCGAT',
#   55.949,
#   57.836),
#  ('orth10362_263-601',
#   3,
#   0,
#   0,
#   0,
#   0,
#   0,
#   2,
#   1,
#   1,
#   0.3773907110269789,
#   184,
#   'CTTCTGCGATGATGTGTCAA',
#   'GAGCTGGAACGTTTCGATG',
#   56.166,
#   56.752),
#  ('orth10362_263-601',
#   4,
#   0,
#   0,
#   0,
#   0,
#   0,
#   2,
#   1,
#   1,
#   0.3767526026554526,
#   177,
#   'GATGATGTGTCAATCCCACC',
#   'GAGCTGGAACGTTTCGATG',
#   56.182,
#   56.752),
#  ('orth10362_263-601',
#   3,
#   1,
#   2,
#   1,
#   1,
#   1,
#   4,
#   2,
#   2,
#   0.3334772725485436,
#   195,
#   'GCCTGCTCTTCGTCAGCrTC',
#   'AACGTTTCGATGTCGAyGCT',
#   56.134,
#   55.923),
#  ('orth10362_263-601',
#   1,
#   1,
#   1,
#   0,
#   1,
#   1,
#   3,
#   1,
#   2,
#   0.33018073673198484,
#   174,
#   'TCTGCGATGATGTGTCAATC',
#   'AACGTTTCGATGTCGAyGCT',
#   55.949,
#   55.923),
#  ('orth10362_263-601',
#   4,
#   1,
#   1,
#   0,
#   1,
#   1,
#   3,
#   1,
#   2,
#   0.3292046806493947,
#   175,
#   'CTTCTGCGATGATGTGTCAA',
#   'ACGTTTCGATGTCGAyGCTT',
#   56.166,
#   55.923),
#  ('orth10362_263-601',
#   2,
#   1,
#   2,
#   1,
#   1,
#   1,
#   4,
#   2,
#   2,
#   0.33242817091024707,
#   194,
#   'GCCTGCTCTTCGTCAGCrTC',
#   'ACGTTTCGATGTCGAyGCTT',
#   56.134,
#   55.923),
#  ('orth10362_263-601',
#   0,
#   1,
#   1,
#   0,
#   1,
#   1,
#   3,
#   1,
#   2,
#   0.3287208645800493,
#   173,
#   'TCTGCGATGATGTGTCAATC',
#   'ACGTTTCGATGTCGAyGCTT',
#   55.949,
#   55.923),
#  ('orth10362_263-601',
#   1,
#   2,
#   1,
#   0,
#   1,
#   1,
#   3,
#   1,
#   2,
#   0.33018073673198484,
#   174,
#   'TCTGCGATGATGTGTCAATC',
#   'AACGTTTCGATGTCGAyGCT',
#   55.949,
#   55.923),
#  ('orth10362_263-601',
#   2,
#   2,
#   3,
#   2,
#   1,
#   2,
#   6,
#   4,
#   2,
#   0.3538222162128477,
#   226,
#   'GCGCCGATGTrAATTCrCCA',
#   'ACGTTTCGATGTCGAyGCTT',
#   56.114,
#   55.923),
#  ('orth10362_263-601',
#   0,
#   2,
#   1,
#   0,
#   1,
#   1,
#   3,
#   1,
#   2,
#   0.3287208645800493,
#   173,
#   'TCTGCGATGATGTGTCAATC',
#   'ACGTTTCGATGTCGAyGCTT',
#   55.949,
#   55.923),
#  ('orth10362_263-601',
#   4,
#   2,
#   3,
#   2,
#   1,
#   2,
#   6,
#   4,
#   2,
#   0.35506021696726514,
#   227,
#   'TGCGCCGATGTrAATTCrCC',
#   'ACGTTTCGATGTCGAyGCTT',
#   56.114,
#   55.923),
#  ('orth10362_263-601',
#   3,
#   2,
#   3,
#   2,
#   1,
#   2,
#   6,
#   4,
#   2,
#   0.35506021696726514,
#   227,
#   'GCGCCGATGTrAATTCrCCA',
#   'AACGTTTCGATGTCGAyGCT',
#   56.114,
#   55.923),
#  ('orth10416_1535-1776',
#   4,
#   2,
#   3,
#   2,
#   1,
#   2,
#   6,
#   4,
#   2,
#   1.2202061693801176,
#   193,
#   'GAGCCGArGATCTGCGmGTG',
#   'CGCTGTATTGACCATkCCAC',
#   56.007,
#   55.477),
#  ('orth10416_1535-1776',
#   2,
#   2,
#   3,
#   2,
#   1,
#   2,
#   6,
#   4,
#   2,
#   1.1800974720194963,
#   163,
#   'AAyGGAGCCGArGATCTGCG',
#   'AATTTCGTCGCATTCCAwAC',
#   55.832,
#   56.223),
#  ('orth10416_1535-1776',
#   1,
#   2,
#   4,
#   2,
#   2,
#   2,
#   8,
#   4,
#   4,
#   1.1650765794969262,
#   161,
#   'GAGCCGArGATCTGCGmGTG',
#   'TyAATTTCGTCGCATTCCAw',
#   56.007,
#   55.633),
#  ('orth10416_1535-1776',
#   3,
#   2,
#   3,
#   2,
#   1,
#   2,
#   6,
#   4,
#   2,
#   1.235477671444048,
#   199,
#   'AAyGGAGCCGArGATCTGCG',
#   'TCCGCTGTATTGACCATkCC',
#   55.832,
#   56.237),
#  ('orth10416_1535-1776',
#   0,
#   2,
#   3,
#   2,
#   1,
#   2,
#   6,
#   4,
#   2,
#   1.221496485047057,
#   195,
#   'GAGCCGArGATCTGCGmGTG',
#   'TCCGCTGTATTGACCATkCC',
#   56.007,
#   56.237),
#  ('orth10425_0-403',
#   0,
#   2,
#   4,
#   2,
#   2,
#   2,
#   8,
#   4,
#   4,
#   1.6617379066062148,
#   227,
#   'GCTTCGyCAATCArTGCTGC',
#   'GCGyAkGCGGAATTCATTGT',
#   54.351,
#   55.766),
#  ('orth10425_0-403',
#   3,
#   2,
#   4,
#   2,
#   2,
#   2,
#   10,
#   4,
#   6,
#   1.4988246476604725,
#   193,
#   'GCTTCGyCAATCArTGCTGC',
#   'yAACACGATCvACGATCAC',
#   54.351,
#   55.812),
#  ('orth10425_0-403',
#   1,
#   2,
#   4,
#   2,
#   2,
#   2,
#   8,
#   4,
#   4,
#   1.6581121408236434,
#   228,
#   'GCTTCGyCAATCArTGCTGC',
#   'AGCGyAkGCGGAATTCATTG',
#   54.351,
#   55.471),
#  ('orth10425_0-403',
#   4,
#   2,
#   4,
#   2,
#   2,
#   2,
#   8,
#   4,
#   4,
#   1.6581121408236434,
#   228,
#   'GCTTCGyCAATCArTGCTGC',
#   'AAGCGyAkGCGGAATTCATTG',
#   54.351,
#   56.247),
#  ('orth10425_0-403',
#   2,
#   2,
#   4,
#   2,
#   2,
#   2,
#   8,
#   4,
#   4,
#   1.6593342224040768,
#   230,
#   'GCTTCGyCAATCArTGCTGC',
#   'CAAGCGyAkGCGGAATTCAT',
#   54.351,
#   55.471),
#  ('orth10425_453-875',
#   2,
#   1,
#   2,
#   1,
#   1,
#   1,
#   4,
#   2,
#   2,
#   0.6102323956865332,
#   163,
#   'GGyCTGATTGGACTCAAAGC',
#   'TGGyTCCCAGCTGCTTGG',
#   54.589,
#   56.223),
#  ('orth10425_453-875',
#   1,
#   1,
#   1,
#   0,
#   1,
#   1,
#   3,
#   1,
#   2,
#   0.7333665061724198,
#   190,
#   'GACTCAAAGCATTCAAGGCT',
#   'TCTGTGAGTCCCArCGGG',
#   56.321,
#   56.853),
#  ('orth10425_453-875',
#   0,
#   1,
#   1,
#   0,
#   1,
#   1,
#   3,
#   1,
#   2,
#   0.7358960505341258,
#   192,
#   'TGGACTCAAAGCATTCAAGG',
#   'TCTGTGAGTCCCArCGGG',
#   55.938,
#   56.853),
#  ('orth10425_453-875',
#   4,
#   1,
#   2,
#   1,
#   1,
#   1,
#   4,
#   2,
#   2,
#   0.6123237611480737,
#   161,
#   'yCTGATTGGACTCAAAGCAT',
#   'CTGGyTCCCAGCTGCTTGG',
#   57.137,
#   57.545),
#  ('orth10425_453-875',
#   3,
#   1,
#   2,
#   1,
#   1,
#   1,
#   4,
#   2,
#   2,
#   0.6131053342695901,
#   162,
#   'GGyCTGATTGGACTCAAAGCA',
#   'TGGyTCCCAGCTGCTTGG',
#   56.443,
#   56.223),
#  ('orth10425_453-875',
#   1,
#   2,
#   2,
#   0,
#   2,
#   2,
#   5,
#   1,
#   4,
#   0.7235219096519724,
#   187,
#   'GACTCAAAGCATTCAAGGCT',
#   'CTGTGAGTCCCArCGGGCrT',
#   56.321,
#   55.499),
#  ('orth10425_453-875',
#   0,
#   2,
#   2,
#   0,
#   2,
#   2,
#   5,
#   1,
#   4,
#   0.7257386533296608,
#   189,
#   'TGGACTCAAAGCATTCAAGG',
#   'CTGTGAGTCCCArCGGGCrT',
#   55.938,
#   55.499),
#  ('orth10425_453-875',
#   2,
#   2,
#   2,
#   0,
#   2,
#   2,
#   5,
#   1,
#   4,
#   0.723155201202589,
#   185,
#   'TGGACTCAAAGCATTCAAGG',
#   'TGAGTCCCArCGGGCrTATGG',
#   55.938,
#   55.499),
#  ('orth10425_453-875',
#   3,
#   2,
#   2,
#   0,
#   2,
#   2,
#   5,
#   1,
#   4,
#   0.7262189214730507,
#   188,
#   'TGGACTCAAAGCATTCAAGG',
#   'CTGTGAGTCCCArCGGGCrTA',
#   55.938,
#   55.461),
#  ('orth10425_453-875',
#   4,
#   2,
#   3,
#   1,
#   2,
#   2,
#   6,
#   2,
#   4,
#   0.7211711413207648,
#   195,
#   'yCTGATTGGACTCAAAGCAT',
#   'CTGTGAGTCCCArCGGGCrT',
#   57.137,
#   55.499),
#  ('orth10436_2323-2604',
#   4,
#   2,
#   4,
#   2,
#   2,
#   2,
#   8,
#   4,
#   4,
#   1.3484910094663307,
#   206,
#   'CTGCAGGGyATACGyAAGAC',
#   'ATTsGwCCACATGCGCACCA',
#   56.899,
#   56.474),
#  ('orth10436_2323-2604',
#   2,
#   2,
#   4,
#   2,
#   2,
#   2,
#   8,
#   4,
#   4,
#   1.2553116185964577,
#   198,
#   'CTGCAGGGyATACGyAAGAC',
#   'ACATGCGCACCATrCGrTTC',
#   56.899,
#   55.536),
#  ('orth10436_2323-2604',
#   1,
#   2,
#   4,
#   2,
#   2,
#   2,
#   8,
#   4,
#   4,
#   1.3077056297285694,
#   213,
#   'ACGGATCTrATGTTyCTGCAG',
#   'CACATGCGCACCATrCGrTT',
#   55.952,
#   55.818),
#  ('orth10436_2323-2604',
#   0,
#   2,
#   4,
#   2,
#   2,
#   2,
#   8,
#   4,
#   4,
#   1.2535098007042063,
#   199,
#   'CTGCAGGGyATACGyAAGAC',
#   'CACATGCGCACCATrCGrTT',
#   56.899,
#   55.818),
#  ('orth10436_2323-2604',
#   3,
#   2,
#   4,
#   2,
#   2,
#   2,
#   8,
#   4,
#   4,
#   1.3471731857824742,
#   205,
#   'CTGCAGGGyATACGyAAGAC',
#   'TTsGwCCACATGCGCACCAT',
#   56.899,
#   56.474),
#  ('orth10437_768-1057',
#   4,
#   1,
#   1,
#   1,
#   0,
#   1,
#   3,
#   2,
#   1,
#   1.5181959930793472,
#   239,
#   'yAAAGTGTTTCGTGACTTC',
#   'GATATGAGTCTCGGTGCATG',
#   56.075,
#   55.826),
#  ('orth10437_768-1057',
#   3,
#   1,
#   2,
#   1,
#   1,
#   1,
#   4,
#   2,
#   2,
#   1.2207598224988563,
#   179,
#   'CGyAAAGTGTTTCGTGACTT',
#   'TGTyGGCTCCACCATATTGC',
#   55.132,
#   55.651),
#  ('orth10437_768-1057',
#   1,
#   1,
#   1,
#   1,
#   0,
#   1,
#   3,
#   2,
#   1,
#   1.5227181621179107,
#   240,
#   'CGyAAAGTGTTTCGTGACTT',
#   'GATATGAGTCTCGGTGCATG',
#   55.132,
#   55.826),
#  ('orth10437_768-1057',
#   2,
#   1,
#   1,
#   1,
#   0,
#   1,
#   3,
#   2,
#   1,
#   1.5225046144688619,
#   238,
#   'yAAAGTGTTTCGTGACTTC',
#   'ATATGAGTCTCGGTGCATGA',
#   56.075,
#   56.13),
#  ('orth10437_768-1057',
#   0,
#   1,
#   1,
#   1,
#   0,
#   1,
#   3,
#   2,
#   1,
#   1.5263801313574306,
#   239,
#   'CGyAAAGTGTTTCGTGACTT',
#   'ATATGAGTCTCGGTGCATGA',
#   55.132,
#   56.13),
#  ('orth10437_768-1057',
#   2,
#   2,
#   2,
#   2,
#   0,
#   2,
#   5,
#   4,
#   1,
#   1.4776039657243423,
#   237,
#   'yAAAGTGTTTCGTGACTTCy',
#   'ATATGAGTCTCGGTGCATGA',
#   55.333,
#   56.13),
#  ('orth10437_768-1057',
#   4,
#   2,
#   4,
#   2,
#   2,
#   2,
#   8,
#   4,
#   4,
#   1.3509252746589555,
#   234,
#   'TGGmCGyAAAGTGTTTCGTG',
#   'TCGGTGCATGAGCGTrTArA',
#   55.414,
#   56.326),
#  ('orth10437_768-1057',
#   3,
#   2,
#   2,
#   2,
#   0,
#   2,
#   5,
#   4,
#   1,
#   1.4752194907977465,
#   238,
#   'yAAAGTGTTTCGTGACTTCy',
#   'GATATGAGTCTCGGTGCATG',
#   55.333,
#   55.826),
#  ('orth10437_768-1057',
#   1,
#   2,
#   2,
#   2,
#   0,
#   2,
#   5,
#   4,
#   1,
#   1.5192035433990796,
#   244,
#   'TGGmCGyAAAGTGTTTCGTG',
#   'GATATGAGTCTCGGTGCATG',
#   55.414,
#   55.826),
#  ('orth10437_768-1057',
#   0,
#   2,
#   2,
#   2,
#   0,
#   2,
#   5,
#   4,
#   1,
#   1.5224279242230487,
#   243,
#   'TGGmCGyAAAGTGTTTCGTG',
#   'ATATGAGTCTCGGTGCATGA',
#   55.414,
#   56.13),
#  ('orth10469_0-801',
#   0,
#   1,
#   2,
#   1,
#   1,
#   1,
#   5,
#   3,
#   2,
#   1.8684245973847569,
#   339,
#   'GATGGdATGATGGATCATGG',
#   'CGTGTTTCTTGyCCATCTACC',
#   53.869,
#   54.909),
#  ('orth10469_0-801',
#   4,
#   1,
#   2,
#   1,
#   1,
#   1,
#   5,
#   3,
#   2,
#   1.8745850753667945,
#   334,
#   'GATGGdATGATGGATCATGG',
#   'GTTTCTTGyCCATCTACCATACC',
#   53.869,
#   55.055),
#  ('orth10469_0-801',
#   3,
#   1,
#   2,
#   1,
#   1,
#   1,
#   5,
#   3,
#   2,
#   1.8676672944133645,
#   337,
#   'GATGGdATGATGGATCATGG',
#   'GTGTTTCTTGyCCATCTACCAT',
#   53.869,
#   54.375),
#  ('orth10469_0-801',
#   2,
#   1,
#   2,
#   1,
#   1,
#   1,
#   5,
#   3,
#   2,
#   1.8694551953789194,
#   338,
#   'GATGGdATGATGGATCATGG',
#   'GTGTTTCTTGyCCATCTACCA',
#   53.869,
#   53.757),
#  ('orth10469_0-801',
#   1,
#   1,
#   2,
#   1,
#   1,
#   1,
#   5,
#   3,
#   2,
#   1.8694551953789194,
#   338,
#   'GATGGdATGATGGATCATGG',
#   'CGTGTTTCTTGyCCATCTACCA',
#   53.869,
#   56.657),
#  ('orth10469_0-801',
#   0,
#   2,
#   4,
#   2,
#   2,
#   2,
#   12,
#   6,
#   6,
#   1.0853251970047275,
#   187,
#   'GATGGdATGATGGATCATGGr',
#   'hCGGCArTTACACTTACGTG',
#   55.568,
#   56.228),
#  ('orth10469_0-801',
#   3,
#   2,
#   4,
#   2,
#   2,
#   2,
#   12,
#   6,
#   6,
#   1.132390537003923,
#   188,
#   'rGATGGdATGATGGATCATGG',
#   'hCGGCArTTACACTTACGTG',
#   56.797,
#   56.228),
#  ('orth10469_0-801',
#   1,
#   2,
#   4,
#   2,
#   2,
#   2,
#   12,
#   6,
#   6,
#   1.080684766023005,
#   185,
#   'TGGdATGATGGATCATGGrGC',
#   'hCGGCArTTACACTTACGTG',
#   55.565,
#   56.228),
#  ('orth10469_0-801',
#   4,
#   2,
#   4,
#   2,
#   2,
#   2,
#   12,
#   6,
#   6,
#   1.1315580144328703,
#   189,
#   'rGATGGdATGATGGATCATG',
#   'hCGGCArTTACACTTACGTG',
#   54.15,
#   56.228),
#  ('orth10469_0-801',
#   2,
#   2,
#   4,
#   2,
#   2,
#   2,
#   12,
#   6,
#   6,
#   1.0853251970047275,
#   187,
#   'ATGGdATGATGGATCATGGr',
#   'hCGGCArTTACACTTACGTG',
#   54.207,
#   56.228),
#  ('orth10473_387-639',
#   3,
#   0,
#   0,
#   0,
#   0,
#   0,
#   2,
#   1,
#   1,
#   0.7840762623934744,
#   209,
#   'CTGGAACAATTGCGATCAAC',
#   'TTATGCTTGCACGTAACTTG',
#   55.653,
#   54.639),
#  ('orth10473_387-639',
#   2,
#   0,
#   0,
#   0,
#   0,
#   0,
#   2,
#   1,
#   1,
#   0.7859487185938683,
#   208,
#   'TGGAACAATTGCGATCAACA',
#   'TTATGCTTGCACGTAACTTG',
#   56.25,
#   54.639),
#  ('orth10473_387-639',
#   0,
#   0,
#   0,
#   0,
#   0,
#   0,
#   2,
#   1,
#   1,
#   0.7859487185938683,
#   208,
#   'TGGAACAATTGCGATCAACA',
#   'CTTATGCTTGCACGTAACTTG',
#   56.25,
#   55.902),
#  ('orth10473_387-639',
#   1,
#   0,
#   0,
#   0,
#   0,
#   0,
#   2,
#   1,
#   1,
#   0.7840762623934744,
#   209,
#   'CTGGAACAATTGCGATCAAC',
#   'CTTATGCTTGCACGTAACTTG',
#   55.653,
#   55.902),
#  ('orth10473_387-639',
#   4,
#   0,
#   0,
#   0,
#   0,
#   0,
#   2,
#   1,
#   1,
#   0.7845905733741612,
#   209,
#   'TGGAACAATTGCGATCAACA',
#   'CTTATGCTTGCACGTAACTT',
#   56.25,
#   54.337),
#  ('orth10473_387-639',
#   1,
#   1,
#   1,
#   0,
#   1,
#   1,
#   3,
#   1,
#   2,
#   0.7569046021993286,
#   171,
#   'TGGAACAATTGCGATCAACA',
#   'CTGGCCAmAGGGATAATTCA',
#   56.25,
#   56.046),
#  ('orth10473_387-639',
#   2,
#   1,
#   1,
#   0,
#   1,
#   1,
#   3,
#   1,
#   2,
#   0.755666724000573,
#   172,
#   'CTGGAACAATTGCGATCAAC',
#   'CTGGCCAmAGGGATAATTCA',
#   55.653,
#   56.046),
#  ('orth10473_387-639',
#   4,
#   1,
#   2,
#   1,
#   1,
#   1,
#   4,
#   2,
#   2,
#   0.7108115457758193,
#   195,
#   'GATCAACAAyTGGGCCCCTT',
#   'TATGCTTGCACGTAACTTGy',
#   55.96,
#   55.474),
#  ('orth10473_387-639',
#   3,
#   1,
#   1,
#   0,
#   1,
#   1,
#   3,
#   1,
#   2,
#   0.7616370806231819,
#   172,
#   'TGGAACAATTGCGATCAACA',
#   'TCTGGCCAmAGGGATAATTC',
#   56.25,
#   55.746),
#  ('orth10473_387-639',
#   0,
#   1,
#   2,
#   1,
#   1,
#   1,
#   4,
#   2,
#   2,
#   0.711163784770569,
#   160,
#   'GATCAACAAyTGGGCCCCTT',
#   'TCTGGCCAmAGGGATAATTC',
#   55.96,
#   55.746),
#  ('orth10473_387-639',
#   0,
#   2,
#   3,
#   1,
#   2,
#   2,
#   6,
#   2,
#   4,
#   0.715068801174997,
#   165,
#   'GATCAACAAyTGGGCCCCTT',
#   'CTGTmTCTGGCCAmAGGGAT',
#   55.96,
#   55.839),
#  ('orth10473_387-639',
#   1,
#   2,
#   2,
#   1,
#   1,
#   1,
#   4,
#   2,
#   2,
#   0.711163784770569,
#   160,
#   'GATCAACAAyTGGGCCCCTT',
#   'TCTGGCCAmAGGGATAATTC',
#   55.96,
#   55.746),
#  ('orth10473_387-639',
#   4,
#   2,
#   4,
#   2,
#   2,
#   2,
#   8,
#   4,
#   4,
#   0.6714315265429308,
#   162,
#   'CAACAAyTGGGCCCCTTyCC',
#   'CTGTmTCTGGCCAmAGGGAT',
#   55.796,
#   55.839),
#  ('orth10473_387-639',
#   3,
#   2,
#   3,
#   1,
#   2,
#   2,
#   6,
#   2,
#   4,
#   0.7097770420153341,
#   161,
#   'GATCAACAAyTGGGCCCCTT',
#   'mTCTGGCCAmAGGGATAATT',
#   55.96,
#   56.307),
#  ('orth10473_387-639',
#   2,
#   2,
#   1,
#   0,
#   1,
#   1,
#   3,
#   1,
#   2,
#   0.7569046021993286,
#   171,
#   'TGGAACAATTGCGATCAACA',
#   'CTGGCCAmAGGGATAATTCA',
#   56.25,
#   56.046),
#  ('orth10483_1160-1888',
#   4,
#   1,
#   2,
#   1,
#   1,
#   1,
#   4,
#   2,
#   2,
#   1.863766240700355,
#   287,
#   'GTTTGGGTGGGyGAGCATAAT',
#   'CGCATGAAATTGTGAAArCGA',
#   55.376,
#   54.956),
#  ('orth10483_1160-1888',
#   0,
#   1,
#   2,
#   1,
#   1,
#   1,
#   4,
#   2,
#   2,
#   1.8632371082672954,
#   285,
#   'TGGGTGGGyGAGCATAATCG',
#   'CGCATGAAATTGTGAAArCGA',
#   56.526,
#   54.956),
#  ('orth10483_1160-1888',
#   1,
#   1,
#   2,
#   1,
#   1,
#   1,
#   4,
#   2,
#   2,
#   1.8634878042644052,
#   284,
#   'TGGGTGGGyGAGCATAATCG',
#   'CGCATGAAATTGTGAAArCGAT',
#   56.526,
#   55.507),
#  ('orth10483_1160-1888',
#   3,
#   1,
#   2,
#   1,
#   1,
#   1,
#   4,
#   2,
#   2,
#   1.8632503879105726,
#   288,
#   'GTTTGGGTGGGyGAGCATAA',
#   'CGCATGAAATTGTGAAArCGA',
#   54.771,
#   54.956),
#  ('orth10483_1160-1888',
#   2,
#   1,
#   2,
#   1,
#   1,
#   1,
#   4,
#   2,
#   2,
#   1.8626264940580937,
#   286,
#   'TGGGTGGGyGAGCATAATCG',
#   'CGCATGAAATTGTGAAArCG',
#   56.526,
#   53.389),
#  ('orth10483_1160-1888',
#   0,
#   2,
#   4,
#   2,
#   2,
#   2,
#   10,
#   4,
#   6,
#   1.8338054039066405,
#   286,
#   'GGGTGGGyGAGCATAATCGy',
#   'dCGCATGAAATTGTGAAArC',
#   56.288,
#   54.309),
#  ('orth10483_1160-1888',
#   3,
#   2,
#   4,
#   2,
#   2,
#   2,
#   10,
#   4,
#   6,
#   1.8316390201273576,
#   285,
#   'GGGTGGGyGAGCATAATCGy',
#   'dCGCATGAAATTGTGAAArCG',
#   56.288,
#   57.231),
#  ('orth10483_1160-1888',
#   2,
#   2,
#   3,
#   2,
#   1,
#   2,
#   6,
#   4,
#   2,
#   1.8316455810479415,
#   284,
#   'GGGTGGGyGAGCATAATCGy',
#   'CGCATGAAATTGTGAAArCGA',
#   56.288,
#   54.956),
#  ('orth10483_1160-1888',
#   1,
#   2,
#   3,
#   1,
#   2,
#   2,
#   8,
#   2,
#   6,
#   1.8657939529763403,
#   287,
#   'TGGGTGGGyGAGCATAATCG',
#   'dCGCATGAAATTGTGAAArC',
#   56.526,
#   54.309),
#  ('orth10483_1160-1888',
#   4,
#   2,
#   2,
#   1,
#   1,
#   1,
#   4,
#   2,
#   2,
#   1.8632371082672954,
#   285,
#   'TGGGTGGGyGAGCATAATCG',
#   'CGCATGAAATTGTGAAArCGA',
#   56.526,
#   54.956),
#  ('orth10502_0-657',
#   1,
#   2,
#   4,
#   2,
#   2,
#   2,
#   12,
#   6,
#   6,
#   2.2331488577828145,
#   265,
#   'AGCATCTTTCAyACGGTdCT',
#   'CTGTCCAyACCTCCCAhGG',
#   54.786,
#   55.873),
#  ('orth10502_0-657',
#   3,
#   2,
#   4,
#   2,
#   2,
#   2,
#   10,
#   6,
#   4,
#   2.2740517335035055,
#   271,
#   'AGCATCTTTCAyACGGTdCT',
#   'AAATGwACTGTCCAyACCTC',
#   54.786,
#   54.675),
#  ('orth10502_0-657',
#   4,
#   2,
#   4,
#   2,
#   2,
#   2,
#   12,
#   6,
#   6,
#   2.2331488577828145,
#   265,
#   'AGCATCTTTCAyACGGTdCT',
#   'ACTGTCCAyACCTCCCAhGG',
#   54.786,
#   57.821),
#  ('orth10502_0-657',
#   0,
#   2,
#   4,
#   2,
#   2,
#   2,
#   10,
#   6,
#   4,
#   2.2761552457276144,
#   270,
#   'AGCATCTTTCAyACGGTdCT',
#   'AATGwACTGTCCAyACCTCC',
#   54.786,
#   56.565),
#  ('orth10502_0-657',
#   2,
#   2,
#   4,
#   2,
#   2,
#   2,
#   10,
#   6,
#   4,
#   2.2761552457276144,
#   270,
#   'AGCATCTTTCAyACGGTdCT',
#   'ATGwACTGTCCAyACCTCC',
#   54.786,
#   55.723),
#  ('orth10532_3220-4034',
#   1,
#   2,
#   4,
#   2,
#   2,
#   2,
#   15,
#   6,
#   9,
#   3.8693181563513783,
#   403,
#   'CCGGdATCAAAATTTGGGTk',
#   'TTGhCGACCCTCTTTbCCCA',
#   55.223,
#   55.514),
#  ('orth10532_3220-4034',
#   0,
#   2,
#   4,
#   2,
#   2,
#   2,
#   15,
#   6,
#   9,
#   3.826450599437154,
#   405,
#   'CCGGdATCAAAATTTGGGTk',
#   'GCTTGhCGACCCTCTTTbCC',
#   55.223,
#   55.607),
#  ('orth10532_3220-4034',
#   4,
#   2,
#   4,
#   2,
#   2,
#   2,
#   15,
#   6,
#   9,
#   3.869565323680843,
#   406,
#   'rGCCGGdATCAAAATTTGG',
#   'TTGhCGACCCTCTTTbCCCA',
#   55.957,
#   55.514),
#  ('orth10532_3220-4034',
#   2,
#   2,
#   4,
#   2,
#   2,
#   2,
#   15,
#   6,
#   9,
#   3.868057109560619,
#   408,
#   'rGCCGGdATCAAAATTTGG',
#   'GCTTGhCGACCCTCTTTbCC',
#   55.957,
#   55.607),
#  ('orth10532_3220-4034',
#   3,
#   2,
#   4,
#   2,
#   2,
#   2,
#   15,
#   6,
#   9,
#   3.8686758853618755,
#   402,
#   'CCGGdATCAAAATTTGGGTk',
#   'TGhCGACCCTCTTTbCCCAT',
#   55.223,
#   55.276),
#  ('orth2374_1109-1760',
#   3,
#   1,
#   2,
#   1,
#   1,
#   1,
#   4,
#   2,
#   2,
#   1.6824345741153282,
#   195,
#   'TGGTTCAATCCGACyGGCAC',
#   'GGGCACmGGAATCTGCGTG',
#   55.264,
#   55.874),
#  ('orth2374_1109-1760',
#   0,
#   1,
#   2,
#   1,
#   1,
#   1,
#   4,
#   2,
#   2,
#   1.677427574778207,
#   193,
#   'TGGTTCAATCCGACyGGCAC',
#   'GGCACmGGAATCTGCGTGAG',
#   55.264,
#   56.112),
#  ('orth2374_1109-1760',
#   2,
#   1,
#   2,
#   1,
#   1,
#   1,
#   4,
#   2,
#   2,
#   1.6693665654307888,
#   191,
#   'TGGTTCAATCCGACyGGCAC',
#   'GCACmGGAATCTGCGTGAGAA',
#   55.264,
#   55.884),
#  ('orth2374_1109-1760',
#   1,
#   1,
#   2,
#   1,
#   1,
#   1,
#   4,
#   2,
#   2,
#   1.6747401790232654,
#   192,
#   'TGGTTCAATCCGACyGGCAC',
#   'GCACmGGAATCTGCGTGAGA',
#   55.264,
#   55.098),
#  ('orth2374_1109-1760',
#   4,
#   1,
#   2,
#   1,
#   1,
#   1,
#   4,
#   2,
#   2,
#   1.6833185983908532,
#   196,
#   'TGGTTCAATCCGACyGGCAC',
#   'TGGGCACmGGAATCTGCGT',
#   55.264,
#   56.19),
#  ('orth2374_1109-1760',
#   1,
#   2,
#   2,
#   1,
#   1,
#   1,
#   4,
#   2,
#   2,
#   1.677427574778207,
#   193,
#   'TGGTTCAATCCGACyGGCAC',
#   'GGCACmGGAATCTGCGTGAG',
#   55.264,
#   56.112),
#  ('orth2374_1109-1760',
#   2,
#   2,
#   3,
#   2,
#   1,
#   2,
#   6,
#   4,
#   2,
#   1.6759913859826219,
#   193,
#   'mTGGTTCAATCCGACyGGCA',
#   'GCACmGGAATCTGCGTGAGA',
#   55.508,
#   55.098),
#  ('orth2374_1109-1760',
#   0,
#   2,
#   3,
#   2,
#   1,
#   2,
#   6,
#   4,
#   2,
#   1.6785544786262818,
#   194,
#   'mTGGTTCAATCCGACyGGCA',
#   'GGCACmGGAATCTGCGTGAG',
#   55.508,
#   56.112),
#  ('orth2374_1109-1760',
#   3,
#   2,
#   3,
#   2,
#   1,
#   2,
#   6,
#   4,
#   2,
#   1.671735793999579,
#   192,
#   'mTGGTTCAATCCGACyGGCA',
#   'GCACmGGAATCTGCGTGAGAA',
#   55.508,
#   55.884),
#  ('orth2374_1109-1760',
#   4,
#   2,
#   3,
#   2,
#   1,
#   2,
#   6,
#   4,
#   2,
#   1.6833185983908534,
#   196,
#   'mTGGTTCAATCCGACyGGCA',
#   'GGGCACmGGAATCTGCGTG',
#   55.508,
#   55.874),
#  ('orth2392_217-872',
#   2,
#   2,
#   4,
#   2,
#   2,
#   2,
#   12,
#   4,
#   8,
#   3.122090690100727,
#   321,
#   'TGCGTAyATyAAGACGAACA',
#   'nGATTCTATCACATCrAGAAATACTT',
#   55.275,
#   53.763),
#  ('orth2392_217-872',
#   1,
#   2,
#   4,
#   2,
#   2,
#   2,
#   12,
#   4,
#   8,
#   3.1233911725002947,
#   320,
#   'TGCGTAyATyAAGACGAACA',
#   'nGATTCTATCACATCrAGAAATACTTC',
#   55.275,
#   54.84),
#  ('orth2392_217-872',
#   4,
#   2,
#   4,
#   2,
#   2,
#   2,
#   12,
#   4,
#   8,
#   3.122090690100727,
#   321,
#   'TGCGTAyATyAAGACGAACAA',
#   'nGATTCTATCACATCrAGAAATACT',
#   56.08,
#   53.017),
#  ('orth2392_217-872',
#   0,
#   2,
#   4,
#   2,
#   2,
#   2,
#   12,
#   4,
#   8,
#   3.121956672119157,
#   322,
#   'TGCGTAyATyAAGACGAACA',
#   'nGATTCTATCACATCrAGAAATACT',
#   55.275,
#   53.017),
#  ('orth2392_217-872',
#   3,
#   2,
#   4,
#   2,
#   2,
#   2,
#   12,
#   4,
#   8,
#   3.1186274121949595,
#   326,
#   'CCTTTGCGTAyATyAAGACG',
#   'nGATTCTATCACATCrAGAAATACT',
#   54.951,
#   53.017),
#  ('orth2445_349-716',
#   1,
#   1,
#   1,
#   0,
#   1,
#   1,
#   3,
#   1,
#   2,
#   1.3020578570295247,
#   187,
#   'GGCCAAAGATATCTTCCGTT',
#   'CATCCATGGAAGCATTkACG',
#   55.503,
#   56.132),
#  ('orth2445_349-716',
#   0,
#   1,
#   1,
#   0,
#   1,
#   1,
#   3,
#   1,
#   2,
#   1.2991795287908825,
#   184,
#   'GGCCAAAGATATCTTCCGTT',
#   'CCATGGAAGCATTkACGATG',
#   55.503,
#   56.132),
#  ('orth2445_349-716',
#   2,
#   1,
#   1,
#   0,
#   1,
#   1,
#   3,
#   1,
#   2,
#   1.3049006658994056,
#   185,
#   'GGCCAAAGATATCTTCCGTT',
#   'TCCATGGAAGCATTkACGAT',
#   55.503,
#   56.151),
#  ('orth2445_349-716',
#   3,
#   1,
#   1,
#   0,
#   1,
#   1,
#   3,
#   1,
#   2,
#   1.3051160920654474,
#   186,
#   'GGCCAAAGATATCTTCCGTT',
#   'ATCCATGGAAGCATTkACGA',
#   55.503,
#   56.151),
#  ('orth2445_349-716',
#   4,
#   1,
#   1,
#   0,
#   1,
#   1,
#   3,
#   1,
#   2,
#   1.2851189973506987,
#   179,
#   'GGCCAAAGATATCTTCCGTT',
#   'GAAGCATTkACGATGTGTGT',
#   55.503,
#   55.636),
#  ('orth2445_349-716',
#   2,
#   2,
#   2,
#   0,
#   2,
#   2,
#   5,
#   1,
#   4,
#   1.3512168575467365,
#   191,
#   'GGCCAAAGATATCTTCCGTT',
#   'wGrGCATCCATGGAAGCATT',
#   55.503,
#   55.864),
#  ('orth2445_349-716',
#   3,
#   2,
#   1,
#   0,
#   1,
#   1,
#   3,
#   1,
#   2,
#   1.3049006658994056,
#   185,
#   'GGCCAAAGATATCTTCCGTT',
#   'TCCATGGAAGCATTkACGAT',
#   55.503,
#   56.151),
#  ('orth2445_349-716',
#   0,
#   2,
#   1,
#   0,
#   1,
#   1,
#   3,
#   1,
#   2,
#   1.2991795287908825,
#   184,
#   'GGCCAAAGATATCTTCCGTT',
#   'CCATGGAAGCATTkACGATG',
#   55.503,
#   56.132),
#  ('orth2445_349-716',
#   1,
#   2,
#   1,
#   0,
#   1,
#   1,
#   3,
#   1,
#   2,
#   1.3020578570295247,
#   187,
#   'GGCCAAAGATATCTTCCGTT',
#   'CATCCATGGAAGCATTkACG',
#   55.503,
#   56.132),
#  ('orth2445_349-716',
#   4,
#   2,
#   1,
#   0,
#   1,
#   1,
#   3,
#   1,
#   2,
#   1.3051160920654474,
#   186,
#   'GGCCAAAGATATCTTCCGTT',
#   'ATCCATGGAAGCATTkACGA',
#   55.503,
#   56.151),
#  ('orth2449_407-1057',
#   2,
#   2,
#   4,
#   2,
#   2,
#   2,
#   15,
#   6,
#   9,
#   1.621385798814095,
#   184,
#   'GAATTTCTTGCCGArGGhAC',
#   'dATGCTCGATATvCGTTG',
#   53.277,
#   53.419),
#  ('orth2449_407-1057',
#   0,
#   2,
#   4,
#   2,
#   2,
#   2,
#   13,
#   4,
#   9,
#   1.7074361529694297,
#   190,
#   'rAATCCyGAATTTCTTGCCGA',
#   'dATGCTCGATATvCGTTG',
#   55.138,
#   53.419),
#  ('orth2449_407-1057',
#   1,
#   2,
#   4,
#   2,
#   2,
#   2,
#   13,
#   4,
#   9,
#   1.7075298810973996,
#   191,
#   'rAATCCyGAATTTCTTGCCG',
#   'dATGCTCGATATvCGTTG',
#   53.528,
#   53.419),
#  ('orth2462_53-471',
#   2,
#   1,
#   2,
#   1,
#   1,
#   1,
#   4,
#   2,
#   2,
#   2.001690582083733,
#   274,
#   'ACCGGTTTCATTGArACACT',
#   'rATAATACCATCCAAATCACT',
#   56.458,
#   54.401),
#  ('orth2462_53-471',
#   1,
#   1,
#   2,
#   1,
#   1,
#   1,
#   4,
#   2,
#   2,
#   2.1094530664506226,
#   281,
#   'CCCAAAArACCGGTTTCATT',
#   'rATAATACCATCCAAATCACTT',
#   55.899,
#   55.232),
#  ('orth2462_53-471',
#   0,
#   1,
#   2,
#   1,
#   1,
#   1,
#   4,
#   2,
#   2,
#   2.1061894040764595,
#   282,
#   'CCCAAAArACCGGTTTCATT',
#   'rATAATACCATCCAAATCACT',
#   55.899,
#   54.401),
#  ('orth2462_53-471',
#   3,
#   1,
#   2,
#   1,
#   1,
#   1,
#   4,
#   2,
#   2,
#   2.004820254135403,
#   273,
#   'ACCGGTTTCATTGArACACT',
#   'rATAATACCATCCAAATCACTT',
#   56.458,
#   55.232),
#  ('orth2462_53-471',
#   4,
#   1,
#   2,
#   1,
#   1,
#   1,
#   4,
#   2,
#   2,
#   1.7305570137249238,
#   232,
#   'AGyATGGGTCAAATGTTCGA',
#   'rATAATACCATCCAAATCACT',
#   55.289,
#   54.401),
#  ('orth2462_53-471',
#   3,
#   2,
#   3,
#   1,
#   2,
#   2,
#   6,
#   2,
#   4,
#   2.1025552918105497,
#   290,
#   'CCCAAAArACCGGTTTCATT',
#   'rATTTCCGCrATAATACCATCC',
#   55.899,
#   56.729),
#  ('orth2462_53-471',
#   4,
#   2,
#   4,
#   2,
#   2,
#   2,
#   8,
#   4,
#   4,
#   1.9094178345740562,
#   274,
#   'CATTGArACACTyCGCCTCA',
#   'rATTTCCGCrATAATACCATCC',
#   55.892,
#   56.729),
#  ('orth2462_53-471',
#   1,
#   2,
#   3,
#   2,
#   1,
#   2,
#   6,
#   4,
#   2,
#   1.913969889500665,
#   266,
#   'CATTGArACACTyCGCCTCA',
#   'rATAATACCATCCAAATCACT',
#   55.892,
#   54.401),
#  ('orth2462_53-471',
#   2,
#   2,
#   3,
#   2,
#   1,
#   2,
#   6,
#   4,
#   2,
#   1.7148270423936876,
#   230,
#   'yATGGGTCAAATGTTCGAkG',
#   'rATAATACCATCCAAATCACT',
#   56.179,
#   54.401),
#  ('orth2462_53-471',
#   0,
#   2,
#   2,
#   1,
#   1,
#   1,
#   4,
#   2,
#   2,
#   2.1061894040764595,
#   282,
#   'CCCAAAArACCGGTTTCATT',
#   'rATAATACCATCCAAATCACT',
#   55.899,
#   54.401),
#  ('orth2463_3252-4336',
#   4,
#   2,
#   4,
#   2,
#   2,
#   2,
#   10,
#   4,
#   6,
#   2.238520763877105,
#   248,
#   'yTGACyGATCAGGCACGCT',
#   'rATAATCGAATTTCTTvACATC',
#   54.777,
#   53.627),
#  ('orth2463_3252-4336',
#   2,
#   2,
#   4,
#   2,
#   2,
#   2,
#   10,
#   4,
#   6,
#   2.2327167204109175,
#   246,
#   'yTGACyGATCAGGCACGCTTT',
#   'rATAATCGAATTTCTTvACATC',
#   56.389,
#   53.627),
#  ('orth2463_3252-4336',
#   3,
#   2,
#   3,
#   1,
#   2,
#   2,
#   8,
#   2,
#   6,
#   2.2327167204109175,
#   246,
#   'TGACyGATCAGGCACGCTTT',
#   'rATAATCGAATTTCTTvACATC',
#   54.6,
#   53.627),
#  ('orth2463_3252-4336',
#   0,
#   2,
#   4,
#   2,
#   2,
#   2,
#   10,
#   4,
#   6,
#   2.2355934523251952,
#   247,
#   'yTGACyGATCAGGCACGCTT',
#   'rATAATCGAATTTCTTvACATC',
#   55.622,
#   53.627),
#  ('orth2463_3252-4336',
#   1,
#   2,
#   4,
#   2,
#   2,
#   2,
#   10,
#   4,
#   6,
#   2.195362562493494,
#   243,
#   'yGATCAGGCACGCTTTATy',
#   'rATAATCGAATTTCTTvACATC',
#   56.148,
#   53.627),
#  ('orth2471_2206-3211',
#   1,
#   2,
#   4,
#   2,
#   2,
#   2,
#   10,
#   6,
#   4,
#   4.539253366477838,
#   372,
#   'rGAAGTdAATCATATGTGCTC',
#   'ATGGCATrAATTGrTGCGCA',
#   53.626,
#   55.38),
#  ('orth2471_2206-3211',
#   4,
#   2,
#   4,
#   2,
#   2,
#   2,
#   10,
#   6,
#   4,
#   4.539961384056533,
#   373,
#   'rGAAGTdAATCATATGTGCTC',
#   'GATGGCATrAATTGrTGCGC',
#   53.626,
#   54.817),
#  ('orth2471_2206-3211',
#   3,
#   2,
#   4,
#   2,
#   2,
#   2,
#   10,
#   6,
#   4,
#   4.536898462859334,
#   371,
#   'rGAAGTdAATCATATGTGCTC',
#   'ATGGCATrAATTGrTGCGCAT',
#   53.626,
#   55.954),
#  ('orth2471_2206-3211',
#   0,
#   2,
#   4,
#   2,
#   2,
#   2,
#   10,
#   6,
#   4,
#   4.536898462859334,
#   371,
#   'rGAAGTdAATCATATGTGCTC',
#   'TGGCATrAATTGrTGCGCAT',
#   53.626,
#   55.38),
#  ('orth2471_2206-3211',
#   2,
#   2,
#   4,
#   2,
#   2,
#   2,
#   10,
#   6,
#   4,
#   4.541723189589347,
#   370,
#   'rGAAGTdAATCATATGTGCTC',
#   'GGCATrAATTGrTGCGCATG',
#   53.626,
#   55.101),
#  ('orth2472_414-1364',
#   2,
#   1,
#   1,
#   1,
#   0,
#   1,
#   3,
#   2,
#   1,
#   2.289707967293083,
#   214,
#   'GATGCyTGGACATGGGGTGG',
#   'TCACAGATGGGATAAGGCTG',
#   55.645,
#   56.691),
#  ('orth2472_414-1364',
#   1,
#   1,
#   2,
#   1,
#   1,
#   1,
#   4,
#   2,
#   2,
#   2.254611060359606,
#   211,
#   'GATGCyTGGACATGGGGTGG',
#   'CAGATGGGATAAGGCTGwCC',
#   55.645,
#   55.577),
#  ('orth2472_414-1364',
#   3,
#   1,
#   2,
#   1,
#   1,
#   1,
#   4,
#   2,
#   2,
#   2.2563963875476745,
#   213,
#   'GATGCyTGGACATGGGGTGG',
#   'CACAGATGGGATAAGGCTGw',
#   55.645,
#   56.738),
#  ('orth2472_414-1364',
#   0,
#   1,
#   1,
#   1,
#   0,
#   1,
#   3,
#   2,
#   1,
#   2.289134710572193,
#   215,
#   'GATGCyTGGACATGGGGTGG',
#   'ATCACAGATGGGATAAGGCT',
#   55.645,
#   55.655),
#  ('orth2472_414-1364',
#   4,
#   1,
#   2,
#   1,
#   1,
#   1,
#   4,
#   2,
#   2,
#   2.8689635462183314,
#   310,
#   'GATGCyTGGACATGGGGTGG',
#   'rATATTCGCATTATTCGGATC',
#   55.645,
#   56.125),
#  ('orth2472_414-1364',
#   4,
#   2,
#   3,
#   2,
#   1,
#   2,
#   6,
#   4,
#   2,
#   4.192673669899651,
#   452,
#   'mATTTTACGCGAATGGTTrC',
#   'CAGATGGGATAAGGCTGwCC',
#   56.027,
#   55.577),
#  ('orth2472_414-1364',
#   3,
#   2,
#   3,
#   2,
#   1,
#   2,
#   6,
#   4,
#   2,
#   2.249606955869088,
#   210,
#   'ATGCyTGGACATGGGGTGGm',
#   'CAGATGGGATAAGGCTGwCC',
#   56.003,
#   55.577),
#  ('orth2472_414-1364',
#   2,
#   2,
#   2,
#   2,
#   0,
#   2,
#   5,
#   4,
#   1,
#   2.2906377943086484,
#   216,
#   'rGATGCyTGGACATGGGGTG',
#   'ATCACAGATGGGATAAGGCT',
#   55.922,
#   55.655),
#  ('orth2472_414-1364',
#   1,
#   2,
#   2,
#   2,
#   0,
#   2,
#   5,
#   4,
#   1,
#   4.23169943729603,
#   456,
#   'mATTTTACGCGAATGGTTrC',
#   'ATCACAGATGGGATAAGGCT',
#   56.027,
#   55.655),
#  ('orth2472_414-1364',
#   0,
#   2,
#   2,
#   2,
#   0,
#   2,
#   5,
#   4,
#   1,
#   2.284655926177632,
#   214,
#   'ATGCyTGGACATGGGGTGGm',
#   'ATCACAGATGGGATAAGGCT',
#   56.003,
#   55.655),
#  ('orth2481_727-1362',
#   4,
#   1,
#   2,
#   1,
#   1,
#   1,
#   4,
#   2,
#   2,
#   1.604234893703598,
#   194,
#   'AATCGyTGTATGTTGCGCG',
#   'TGCTTyCGACTGGTCTTCAC',
#   54.13,
#   56.719),
#  ('orth2481_727-1362',
#   3,
#   1,
#   2,
#   1,
#   1,
#   1,
#   4,
#   2,
#   2,
#   1.5999173642078854,
#   193,
#   'ATCGyTGTATGTTGCGCGT',
#   'TGCTTyCGACTGGTCTTCAC',
#   55.205,
#   56.719),
#  ('orth2481_727-1362',
#   0,
#   1,
#   2,
#   1,
#   1,
#   1,
#   4,
#   2,
#   2,
#   1.5999173642078854,
#   193,
#   'AATCGyTGTATGTTGCGCGT',
#   'TGCTTyCGACTGGTCTTCAC',
#   56.02,
#   56.719),
#  ('orth2481_727-1362',
#   2,
#   1,
#   2,
#   1,
#   1,
#   1,
#   4,
#   2,
#   2,
#   1.5999173642078854,
#   193,
#   'AATCGyTGTATGTTGCGCGT',
#   'GCTTyCGACTGGTCTTCAC',
#   56.02,
#   54.812),
#  ('orth2481_727-1362',
#   1,
#   1,
#   2,
#   1,
#   1,
#   1,
#   4,
#   2,
#   2,
#   1.5979842466168093,
#   194,
#   'AATCGyTGTATGTTGCGCGT',
#   'TGCTTyCGACTGGTCTTCA',
#   56.02,
#   55.101),
#  ('orth2481_727-1362',
#   4,
#   2,
#   4,
#   2,
#   2,
#   2,
#   8,
#   4,
#   4,
#   1.5455363191359968,
#   195,
#   'CGyTGTATGTTGCGCGTrCA',
#   'GGCArTGCTTyCGACTGGTC',
#   55.616,
#   56.076),
#  ('orth2481_727-1362',
#   2,
#   2,
#   4,
#   2,
#   2,
#   2,
#   10,
#   6,
#   4,
#   1.9060199094251484,
#   258,
#   'AAGCAyCGGTGTCChACAGA',
#   'GGCArTGCTTyCGACTGGTC',
#   56.222,
#   56.076),
#  ('orth2481_727-1362',
#   1,
#   2,
#   4,
#   2,
#   2,
#   2,
#   8,
#   4,
#   4,
#   1.5451173507561524,
#   197,
#   'ATCGyTGTATGTTGCGCGTr',
#   'GGCArTGCTTyCGACTGGTC',
#   56.197,
#   56.076),
#  ('orth2481_727-1362',
#   3,
#   2,
#   3,
#   1,
#   2,
#   2,
#   6,
#   2,
#   4,
#   2.0373314660997,
#   235,
#   'AATCGyTGTATGTTGCGCGT',
#   'ACACGCCArCAAGAyTCACG',
#   56.02,
#   55.587),
#  ('orth2481_727-1362',
#   0,
#   2,
#   3,
#   1,
#   2,
#   2,
#   6,
#   2,
#   4,
#   1.6002576298485056,
#   198,
#   'AATCGyTGTATGTTGCGCGT',
#   'GGCArTGCTTyCGACTGGTC',
#   56.02,
#   56.076),
#  ('orth2506_156-838',
#   0,
#   2,
#   4,
#   2,
#   2,
#   2,
#   8,
#   4,
#   4,
#   2.8175034775787062,
#   177,
#   'GGTCCAAAyGGyATGGTTGG',
#   'GCACCATCGTTyTCCAArCGA',
#   54.835,
#   55.924),
#  ('orth2506_156-838',
#   1,
#   2,
#   4,
#   2,
#   2,
#   2,
#   8,
#   4,
#   4,
#   2.813185975888352,
#   178,
#   'GGTCCAAAyGGyATGGTTGG',
#   'GCACCATCGTTyTCCAArCG',
#   54.835,
#   54.379),
#  ('orth2506_156-838',
#   2,
#   2,
#   4,
#   2,
#   2,
#   2,
#   8,
#   4,
#   4,
#   2.861864651047678,
#   182,
#   'GGTCCAAAyGGyATGGTTGG',
#   'GCTTTrGCACCATCGTTyTCCA',
#   54.835,
#   55.662),
#  ('orth2506_156-838',
#   4,
#   2,
#   4,
#   2,
#   2,
#   2,
#   8,
#   4,
#   4,
#   2.860237727946005,
#   183,
#   'GGTCCAAAyGGyATGGTTGG',
#   'GCTTTrGCACCATCGTTyTCC',
#   54.835,
#   53.899),
#  ('orth2506_156-838',
#   3,
#   2,
#   4,
#   2,
#   2,
#   2,
#   8,
#   4,
#   4,
#   2.812585948526302,
#   176,
#   'GGTCCAAAyGGyATGGTTGG',
#   'GCACCATCGTTyTCCAArCGAT',
#   54.835,
#   56.44),
#  ('orth2514_545-1322',
#   1,
#   1,
#   2,
#   1,
#   1,
#   1,
#   4,
#   2,
#   2,
#   1.0825266686610369,
#   175,
#   'AGCTGGAAyTCTTGGAATATACC',
#   'ACCAGAGCCATAACCGCCrTA',
#   53.958,
#   56.012),
#  ('orth2514_545-1322',
#   0,
#   1,
#   2,
#   1,
#   1,
#   1,
#   4,
#   2,
#   2,
#   1.0899865495363217,
#   176,
#   'AGCTGGAAyTCTTGGAATATACC',
#   'ACCAGAGCCATAACCGCCrT',
#   53.958,
#   56.077),
#  ('orth2514_545-1322',
#   4,
#   1,
#   2,
#   1,
#   1,
#   1,
#   4,
#   2,
#   2,
#   1.625042641277562,
#   283,
#   'AGCTGGAAyTCTTGGAATATACC',
#   'TATGGwGGTTGTGTTGCACT',
#   53.958,
#   54.327),
#  ('orth2514_545-1322',
#   3,
#   1,
#   2,
#   1,
#   1,
#   1,
#   4,
#   2,
#   2,
#   1.0850010087424857,
#   174,
#   'AGCTGGAAyTCTTGGAATATACC',
#   'CCAGAGCCATAACCGCCrTAG',
#   53.958,
#   55.446),
#  ('orth2514_545-1322',
#   2,
#   1,
#   2,
#   1,
#   1,
#   1,
#   4,
#   2,
#   2,
#   1.0962444459705039,
#   180,
#   'AGCTGGAAyTCTTGGAATATACC',
#   'rTAACCAGAGCCATAACCG',
#   53.958,
#   55.664),
#  ('orth2514_545-1322',
#   4,
#   2,
#   3,
#   2,
#   1,
#   2,
#   6,
#   4,
#   2,
#   1.940439073427612,
#   332,
#   'TAyCAAGGkTGGGGTGCACC',
#   'ACCAGAGCCATAACCGCCrT',
#   55.622,
#   56.077),
#  ('orth2514_545-1322',
#   0,
#   2,
#   3,
#   2,
#   1,
#   2,
#   6,
#   4,
#   2,
#   1.9166544021993117,
#   329,
#   'CAAGGkTGGGGTGCACCwCC',
#   'ACCAGAGCCATAACCGCCrT',
#   56.075,
#   56.077),
#  ('orth2514_545-1322',
#   1,
#   2,
#   3,
#   2,
#   1,
#   2,
#   8,
#   6,
#   2,
#   1.1559222889141803,
#   191,
#   'TCmGGTGGTGGhAGCTGGAA',
#   'ACCAGAGCCATAACCGCCrT',
#   55.871,
#   56.077),
#  ('orth2514_545-1322',
#   3,
#   2,
#   3,
#   2,
#   1,
#   2,
#   8,
#   6,
#   2,
#   1.1026534089801927,
#   187,
#   'GTGGTGGhAGCTGGAAyTCT',
#   'ACCAGAGCCATAACCGCCrT',
#   55.678,
#   56.077),
#  ('orth2514_545-1322',
#   2,
#   2,
#   3,
#   2,
#   1,
#   2,
#   8,
#   6,
#   2,
#   1.1575469670679286,
#   192,
#   'TTCmGGTGGTGGhAGCTGGA',
#   'ACCAGAGCCATAACCGCCrT',
#   55.871,
#   56.077),
#  ('orth2522_0-1203',
#   4,
#   2,
#   4,
#   2,
#   2,
#   2,
#   14,
#   8,
#   6,
#   5.892261975986596,
#   518,
#   'TGGTGyACCATTGGnGGAG',
#   'wATACCAATdATCCAAGC',
#   54.105,
#   53.026),
#  ('orth2522_0-1203',
#   0,
#   2,
#   4,
#   2,
#   2,
#   2,
#   14,
#   8,
#   6,
#   5.887242488857127,
#   517,
#   'TGGTGyACCATTGGnGGAGT',
#   'TCAACwATACCAATdATCCAAGC',
#   56.119,
#   54.336),
#  ('orth2522_0-1203',
#   2,
#   2,
#   4,
#   2,
#   2,
#   2,
#   14,
#   8,
#   6,
#   5.892261975986596,
#   518,
#   'TGGTGyACCATTGGnGGAG',
#   'TCAACwATACCAATdATCCAAGC',
#   54.105,
#   54.336),
#  ('orth2522_0-1203',
#   1,
#   2,
#   4,
#   2,
#   2,
#   2,
#   14,
#   8,
#   6,
#   5.887242488857127,
#   517,
#   'TGGTGyACCATTGGnGGAGT',
#   'wATACCAATdATCCAAGC',
#   56.119,
#   53.026),
#  ('orth2522_0-1203',
#   3,
#   2,
#   4,
#   2,
#   2,
#   2,
#   14,
#   8,
#   6,
#   5.887242488857127,
#   517,
#   'GGTGyACCATTGGnGGAGT',
#   'TCAACwATACCAATdATCCAAGC',
#   54.101,
#   54.336),
#  ('orth2538_336-1223',
#   1,
#   2,
#   4,
#   2,
#   2,
#   2,
#   10,
#   4,
#   6,
#   3.3694554456592374,
#   273,
#   'TCATGCTGGATGTGGArAAr',
#   'dGACATGCGATArTTGAGTTC',
#   56.605,
#   53.121),
#  ('orth2538_336-1223',
#   3,
#   2,
#   4,
#   2,
#   2,
#   2,
#   12,
#   6,
#   6,
#   3.435287780293155,
#   276,
#   'hTTCATGCTGGATGTGGAr',
#   'dGACATGCGATArTTGAGTTC',
#   56.163,
#   53.121),
#  ('orth2538_336-1223',
#   4,
#   2,
#   4,
#   2,
#   2,
#   2,
#   12,
#   6,
#   6,
#   3.4324374708975793,
#   275,
#   'hTTCATGCTGGATGTGGArA',
#   'dGACATGCGATArTTGAGTTC',
#   57.256,
#   53.121),
#  ('orth2538_336-1223',
#   2,
#   2,
#   3,
#   1,
#   2,
#   2,
#   9,
#   3,
#   6,
#   3.4512552437735615,
#   277,
#   'CGhTTCATGCTGGATGTGGA',
#   'dGACATGCGATArTTGAGTTC',
#   55.299,
#   53.121),
#  ('orth2538_336-1223',
#   0,
#   2,
#   3,
#   1,
#   2,
#   2,
#   8,
#   2,
#   6,
#   3.431363640291154,
#   274,
#   'TTCATGCTGGATGTGGArAA',
#   'dGACATGCGATArTTGAGTTC',
#   56.203,
#   53.121),
#  ('orth2544_667-1171',
#   3,
#   2,
#   4,
#   2,
#   2,
#   2,
#   12,
#   6,
#   6,
#   3.163287103189464,
#   307,
#   'bCAGAAGCAyAAAGGTTT',
#   'CATCCATbGCCTGyTTGTTGGC',
#   53.163,
#   55.665),
#  ('orth2544_667-1171',
#   2,
#   2,
#   4,
#   2,
#   2,
#   2,
#   10,
#   4,
#   6,
#   2.535400373541608,
#   244,
#   'rGArCAAATGAATGGCGC',
#   'ATCCATbGCCTGyTTGTTGGC',
#   53.868,
#   54.134),
#  ('orth2544_667-1171',
#   1,
#   2,
#   4,
#   2,
#   2,
#   2,
#   10,
#   4,
#   6,
#   2.535400373541608,
#   244,
#   'rGArCAAATGAATGGCGC',
#   'TCCATbGCCTGyTTGTTGGC',
#   53.868,
#   53.481),
#  ('orth2544_667-1171',
#   0,
#   2,
#   4,
#   2,
#   2,
#   2,
#   10,
#   4,
#   6,
#   2.535400373541608,
#   244,
#   'rGArCAAATGAATGGCGC',
#   'CATCCATbGCCTGyTTGTTGGC',
#   53.868,
#   55.665),
#  ('orth2544_667-1171',
#   4,
#   2,
#   4,
#   2,
#   2,
#   2,
#   12,
#   6,
#   6,
#   3.163287103189464,
#   307,
#   'bCAGAAGCAyAAAGGTTT',
#   'TCCATbGCCTGyTTGTTGGC',
#   53.163,
#   53.481),
#  ('orth2553_637-1195',
#   0,
#   2,
#   2,
#   2,
#   0,
#   2,
#   5,
#   4,
#   1,
#   2.358316640043723,
#   167,
#   'yATGCTTAAGAATCGrGTACG',
#   'CATGCTCCAGTCTTCCATTT',
#   55.452,
#   55.705),
#  ('orth2553_637-1195',
#   3,
#   2,
#   3,
#   2,
#   1,
#   2,
#   6,
#   4,
#   2,
#   2.365060244818467,
#   171,
#   'yATGCTTAAGAATCGrGTACG',
#   'GyGACATGCTCCAGTCTTCC',
#   55.452,
#   55.027),
#  ('orth2553_637-1195',
#   1,
#   2,
#   2,
#   2,
#   0,
#   2,
#   5,
#   4,
#   1,
#   2.359977566380737,
#   166,
#   'yATGCTTAAGAATCGrGTACG',
#   'ATGCTCCAGTCTTCCATTTC',
#   55.452,
#   55.411),
#  ('orth2553_637-1195',
#   4,
#   2,
#   2,
#   2,
#   0,
#   2,
#   5,
#   4,
#   1,
#   2.3622225558619854,
#   169,
#   'yATGCTTAAGAATCGrGTACG',
#   'ACATGCTCCAGTCTTCCAT',
#   55.452,
#   55.989),
#  ('orth2553_637-1195',
#   2,
#   2,
#   2,
#   2,
#   0,
#   2,
#   5,
#   4,
#   1,
#   2.36081965728288,
#   168,
#   'yATGCTTAAGAATCGrGTACG',
#   'ACATGCTCCAGTCTTCCATT',
#   55.452,
#   56.81),
#  ('orth2556_0-869',
#   4,
#   0,
#   0,
#   0,
#   0,
#   0,
#   2,
#   1,
#   1,
#   3.1587399035006136,
#   461,
#   'CGTATACGCAAAACACAACA',
#   'AGCAACTATGAGACCCAACA',
#   54.981,
#   56.453),
#  ('orth2556_0-869',
#   2,
#   0,
#   0,
#   0,
#   0,
#   0,
#   2,
#   1,
#   1,
#   3.1580540021646613,
#   457,
#   'CGTATACGCAAAACACAACA',
#   'ACTATGAGACCCAACACAGT',
#   54.981,
#   55.779),
#  ('orth2556_0-869',
#   1,
#   0,
#   0,
#   0,
#   0,
#   0,
#   2,
#   1,
#   1,
#   3.1559888597352255,
#   455,
#   'CGTATACGCAAAACACAACA',
#   'TATGAGACCCAACACAGTCA',
#   54.981,
#   55.793),
#  ('orth2556_0-869',
#   3,
#   0,
#   0,
#   0,
#   0,
#   0,
#   2,
#   1,
#   1,
#   3.157098452775955,
#   460,
#   'CGTATACGCAAAACACAACA',
#   'GCAACTATGAGACCCAACAC',
#   54.981,
#   56.432),
#  ('orth2556_0-869',
#   0,
#   0,
#   0,
#   0,
#   0,
#   0,
#   2,
#   1,
#   1,
#   3.1524666926032716,
#   450,
#   'CGTATACGCAAAACACAACA',
#   'GACCCAACACAGTCAAACAT',
#   54.981,
#   56.166),
#  ('orth2556_0-869',
#   4,
#   1,
#   2,
#   1,
#   1,
#   1,
#   5,
#   3,
#   2,
#   4.646092936838969,
#   613,
#   'GACAGATTAGCCGCACTbCA',
#   'TCCATGAACATGTCGTGyAG',
#   56.572,
#   56.111),
#  ('orth2556_0-869',
#   1,
#   1,
#   1,
#   1,
#   0,
#   1,
#   3,
#   2,
#   1,
#   0.6137038450533209,
#   161,
#   'GACATGTTCATGGAyATGGC',
#   'AGCAACTATGAGACCCAACA',
#   55.96,
#   56.453),
#  ('orth2556_0-869',
#   0,
#   1,
#   1,
#   1,
#   0,
#   1,
#   3,
#   2,
#   1,
#   0.6134854987404014,
#   160,
#   'GACATGTTCATGGAyATGGC',
#   'GCAACTATGAGACCCAACAC',
#   55.96,
#   56.432),
#  ('orth2556_0-869',
#   2,
#   1,
#   2,
#   1,
#   1,
#   1,
#   4,
#   2,
#   2,
#   0.6191292368926474,
#   164,
#   'GACATGTTCATGGAyATGGC',
#   'TGmAGCAACTATGAGACCCA',
#   55.96,
#   56.499),
#  ('orth2556_0-869',
#   3,
#   1,
#   2,
#   1,
#   1,
#   1,
#   4,
#   2,
#   2,
#   0.6170600340246607,
#   163,
#   'GACATGTTCATGGAyATGGC',
#   'GmAGCAACTATGAGACCCAA',
#   55.96,
#   55.389),
#  ('orth2556_0-869',
#   0,
#   2,
#   3,
#   2,
#   1,
#   2,
#   6,
#   4,
#   2,
#   2.4176061178269044,
#   301,
#   'CArCArAACAAATCGTCCGC',
#   'TCCATGAACATGTCGTGyAG',
#   56.013,
#   56.111),
#  ('orth2556_0-869',
#   4,
#   2,
#   4,
#   2,
#   2,
#   2,
#   8,
#   4,
#   4,
#   3.0372857270794302,
#   448,
#   'CArCArAACAAATCGTCCGC',
#   'ATrATCTTCTTTCGrCGCGC',
#   56.013,
#   56.211),
#  ('orth2556_0-869',
#   2,
#   2,
#   2,
#   2,
#   0,
#   2,
#   5,
#   4,
#   1,
#   3.14733319889683,
#   477,
#   'CArCArAACAAATCGTCCGC',
#   'GACCCAACACAGTCAAACAT',
#   56.013,
#   56.166),
#  ('orth2556_0-869',
#   3,
#   2,
#   2,
#   2,
#   0,
#   2,
#   5,
#   4,
#   1,
#   3.151865771235094,
#   482,
#   'CArCArAACAAATCGTCCGC',
#   'TATGAGACCCAACACAGTCA',
#   56.013,
#   55.793),
#  ('orth2556_0-869',
#   1,
#   2,
#   4,
#   2,
#   2,
#   2,
#   8,
#   4,
#   4,
#   2.333890247336975,
#   300,
#   'CArCArAACAAATCGTCCGC',
#   'CCATGAACATGTCGTGyAGy',
#   56.013,
#   56.166),
#  ('orth2566_1289-1740',
#   2,
#   2,
#   3,
#   1,
#   2,
#   2,
#   8,
#   2,
#   6,
#   2.4417163336772205,
#   199,
#   'CGCATGGCTGATATGTTyAC',
#   'GwATGCCbACACCACGTTT',
#   56.235,
#   54.921),
#  ('orth2566_1289-1740',
#   3,
#   2,
#   4,
#   2,
#   2,
#   2,
#   10,
#   4,
#   6,
#   2.402336531353549,
#   198,
#   'CGCATGGCTGATATGTTyACr',
#   'TGwATGCCbACACCACGTTT',
#   55.52,
#   56.863),
#  ('orth2566_1289-1740',
#   1,
#   2,
#   3,
#   1,
#   2,
#   2,
#   8,
#   2,
#   6,
#   2.447780928768016,
#   200,
#   'CGCATGGCTGATATGTTyAC',
#   'TGwATGCCbACACCACGTT',
#   56.235,
#   56.058),
#  ('orth2566_1289-1740',
#   0,
#   2,
#   3,
#   1,
#   2,
#   2,
#   8,
#   2,
#   6,
#   2.4417163336772205,
#   199,
#   'CGCATGGCTGATATGTTyAC',
#   'TGwATGCCbACACCACGTTT',
#   56.235,
#   56.863),
#  ('orth2566_1289-1740',
#   4,
#   2,
#   4,
#   2,
#   2,
#   2,
#   10,
#   4,
#   6,
#   2.4065060756935197,
#   199,
#   'CGCATGGCTGATATGTTyACr',
#   'TGwATGCCbACACCACGTT',
#   55.52,
#   56.058),
#  ('orth2586_948-1620',
#   4,
#   2,
#   4,
#   2,
#   2,
#   2,
#   8,
#   4,
#   4,
#   1.7067901380383848,
#   167,
#   'CArGCCAGCTTCGAyCACTG',
#   'GCAGGAyGCGTATTTsGATTCGT',
#   56.02,
#   55.721),
#  ('orth2586_948-1620',
#   1,
#   2,
#   4,
#   2,
#   2,
#   2,
#   8,
#   4,
#   4,
#   1.674085092671164,
#   172,
#   'GCCAGCTTCGAyCACTGyGA',
#   'TTyAGGCAGGAyGCGTATTT',
#   56.183,
#   53.991),
#  ('orth2586_948-1620',
#   0,
#   2,
#   4,
#   2,
#   2,
#   2,
#   8,
#   4,
#   4,
#   1.7254710462767486,
#   175,
#   'CArGCCAGCTTCGAyCACTG',
#   'TTyAGGCAGGAyGCGTATTT',
#   56.02,
#   53.991),
#  ('orth2586_948-1620',
#   3,
#   2,
#   4,
#   2,
#   2,
#   2,
#   8,
#   4,
#   4,
#   1.674085092671164,
#   172,
#   'GCCAGCTTCGAyCACTGyGA',
#   'yAGGCAGGAyGCGTATTT',
#   56.183,
# ...
#   53.83,
#   54.148),
#  ('orth3696_1155-1653',
#   2,
#   2,
#   4,
#   2,
#   2,
#   2,
#   8,
#   4,
#   4,
#   1.3922617741697003,
#   176,
#   'TGCGTACyATTGTyGAAATGGAAA',
#   'yAAATTCTGTACrAAAGTTATTGG',
#   54.03,
#   54.148),
#  ('orth3696_1155-1653',
#   0,
#   2,
#   4,
#   2,
#   2,
#   2,
#   8,
#   4,
#   4,
#   1.3905396372933072,
#   177,
#   'TGCGTACyATTGTyGAAATGGAA',
#   'yAAATTCTGTACrAAAGTTATTGG',
#   53.245,
#   54.148),
#  ('orth3699_623-1810',
#   0,
#   1,
#   2,
#   1,
#   1,
#   1,
#   5,
#   3,
#   2,
#   10.710881712814379,
#   820,
#   'TbTGCATGTGGTGGGAGAG',
#   'CGGAArATGGGTTCATTGTG',
#   54.626,
#   56.19),
#  ('orth3699_623-1810',
#   3,
#   1,
#   2,
#   1,
#   1,
#   1,
#   5,
#   3,
#   2,
#   10.593206562560853,
#   796,
#   'TbTGCATGTGGTGGGAGAG',
#   'GTGCAACGGTrGGATGTGT',
#   54.626,
#   56.01),
#  ('orth3699_623-1810',
#   4,
#   1,
#   2,
#   1,
#   1,
#   1,
#   4,
#   2,
#   2,
#   10.55414818100367,
#   793,
#   'GCATGTGGTGGGAGAGyAA',
#   'GTGCAACGGTrGGATGTGT',
#   57.71,
#   56.01),
#  ('orth3699_623-1810',
#   1,
#   1,
#   2,
#   1,
#   1,
#   1,
#   4,
#   2,
#   2,
#   10.669326409542421,
#   817,
#   'GCATGTGGTGGGAGAGyAA',
#   'CGGAArATGGGTTCATTGTG',
#   57.71,
#   56.19),
#  ('orth3699_623-1810',
#   2,
#   1,
#   2,
#   1,
#   1,
#   1,
#   4,
#   2,
#   2,
#   10.671117521061658,
#   818,
#   'GCATGTGGTGGGAGAGyA',
#   'CGGAArATGGGTTCATTGTG',
#   56.902,
#   56.19),
#  ('orth3699_623-1810',
#   2,
#   2,
#   3,
#   2,
#   1,
#   2,
#   8,
#   6,
#   2,
#   10.671660513593837,
#   819,
#   'TbTGCATGTGGTGGGAGAGy',
#   'CGGAArATGGGTTCATTGTG',
#   56.359,
#   56.19),
#  ('orth3699_623-1810',
#   4,
#   2,
#   3,
#   2,
#   1,
#   2,
#   6,
#   4,
#   2,
#   10.631214360003478,
#   815,
#   'CATGTGGTGGGAGAGyAAyA',
#   'CGGAArATGGGTTCATTGTG',
#   56.567,
#   56.19),
#  ('orth3699_623-1810',
#   3,
#   2,
#   3,
#   2,
#   1,
#   2,
#   8,
#   6,
#   2,
#   10.710881712814379,
#   820,
#   'rTbTGCATGTGGTGGGAGAG',
#   'CGGAArATGGGTTCATTGTG',
#   56.535,
#   56.19),
#  ('orth3699_623-1810',
#   0,
#   2,
#   3,
#   2,
#   1,
#   2,
#   8,
#   6,
#   2,
#   7.470911330225877,
#   539,
#   'dATGTCACGTTTTGCyGAGG',
#   'CGGAArATGGGTTCATTGTG',
#   55.915,
#   56.19),
#  ('orth3699_623-1810',
#   1,
#   2,
#   3,
#   2,
#   1,
#   2,
#   6,
#   4,
#   2,
#   10.631236842015047,
#   814,
#   'ATGTGGTGGGAGAGyAAyAA',
#   'CGGAArATGGGTTCATTGTG',
#   55.757,
#   56.19),
#  ('orth3728_2622-2823',
#   0,
#   2,
#   2,
#   2,
#   0,
#   2,
#   5,
#   4,
#   1,
#   1.0272397789810854,
#   161,
#   'ATGGGTGGyGArCTTCCCGC',
#   'CTCTAAGTTGCAGCGATCAA',
#   57.953,
#   55.879),
#  ('orth3728_2622-2823',
#   1,
#   2,
#   2,
#   2,
#   0,
#   2,
#   5,
#   4,
#   1,
#   1.0246847911687087,
#   160,
#   'ATGGGTGGyGArCTTCCCGC',
#   'TCTAAGTTGCAGCGATCAAC',
#   57.953,
#   56.173),
#  ('orth3728_2622-2823',
#   4,
#   2,
#   2,
#   2,
#   0,
#   2,
#   5,
#   4,
#   1,
#   1.0235804344065929,
#   161,
#   'ATGGGTGGyGArCTTCCCG',
#   'TCTAAGTTGCAGCGATCAAC',
#   54.536,
#   56.173),
#  ('orth3728_2622-2823',
#   3,
#   2,
#   2,
#   2,
#   0,
#   2,
#   5,
#   4,
#   1,
#   1.0259266661222928,
#   162,
#   'ATGGGTGGyGArCTTCCCG',
#   'CTCTAAGTTGCAGCGATCAA',
#   54.536,
#   55.879),
#  ('orth3728_2622-2823',
#   2,
#   2,
#   2,
#   2,
#   0,
#   2,
#   5,
#   4,
#   1,
#   1.0272397789810854,
#   161,
#   'TGGGTGGyGArCTTCCCGC',
#   'CTCTAAGTTGCAGCGATCAA',
#   57.445,
#   55.879),
#  ('orth3748_1084-1777',
#   4,
#   2,
#   4,
#   2,
#   2,
#   2,
#   10,
#   6,
#   4,
#   1.7417148763791703,
#   230,
#   'TTCTCCAyCChATGCAGCAAG',
#   'TCGCGyAACAAACTAATyAC',
#   55.687,
#   53.875),
#  ('orth3748_1084-1777',
#   3,
#   2,
#   4,
#   2,
#   2,
#   2,
#   10,
#   6,
#   4,
#   1.1146531332531577,
#   172,
#   'GAhAArGCAGCCTTCTCGAT',
#   'TCGCGyAACAAACTAATyAC',
#   54.746,
#   53.875),
#  ('orth3748_1084-1777',
#   0,
#   2,
#   4,
#   2,
#   2,
#   2,
#   8,
#   4,
#   4,
#   1.0239065227577668,
#   167,
#   'rGCAGCCTTCTCGATmTGTT',
#   'TCGCGyAACAAACTAATyAC',
#   56.27,
#   53.875),
#  ('orth3748_1084-1777',
#   2,
#   2,
#   4,
#   2,
#   2,
#   2,
#   10,
#   6,
#   4,
#   1.7417148763791703,
#   230,
#   'TCTCCAyCChATGCAGCAAG',
#   'TCGCGyAACAAACTAATyAC',
#   54.866,
#   53.875),
#  ('orth3748_1084-1777',
#   1,
#   2,
#   4,
#   2,
#   2,
#   2,
#   10,
#   6,
#   4,
#   1.7415002101206107,
#   229,
#   'CTCCAyCChATGCAGCAAGT',
#   'TCGCGyAACAAACTAATyAC',
#   55.156,
#   53.875),
#  ('orth3767_964-1531',
#   0,
#   1,
#   2,
#   1,
#   1,
#   1,
#   4,
#   2,
#   2,
#   1.7726864250365908,
#   178,
#   'GTACAyAAGACTGTACGTGC',
#   'GGACAACGCCAATTGTAkAG',
#   55.354,
#   56.223),
#  ('orth3767_964-1531',
#   3,
#   1,
#   2,
#   1,
#   1,
#   1,
#   4,
#   2,
#   2,
#   1.7724346693607036,
#   177,
#   'GTACAyAAGACTGTACGTGC',
#   'GACAACGCCAATTGTAkAGA',
#   55.354,
#   55.185),
#  ('orth3767_964-1531',
#   1,
#   1,
#   2,
#   1,
#   1,
#   1,
#   4,
#   2,
#   2,
#   1.7724346693607036,
#   177,
#   'TACAyAAGACTGTACGTGCT',
#   'GGACAACGCCAATTGTAkAG',
#   55.34,
#   56.223),
#  ('orth3767_964-1531',
#   2,
#   1,
#   2,
#   1,
#   1,
#   1,
#   4,
#   2,
#   2,
#   1.771724668060281,
#   176,
#   'ACAyAAGACTGTACGTGCTG',
#   'GGACAACGCCAATTGTAkAG',
#   56.986,
#   56.223),
#  ('orth3767_964-1531',
#   4,
#   1,
#   2,
#   1,
#   1,
#   1,
#   4,
#   2,
#   2,
#   1.7721292278324456,
#   176,
#   'TACAyAAGACTGTACGTGCT',
#   'GACAACGCCAATTGTAkAGA',
#   55.34,
#   55.185),
#  ('orth3767_964-1531',
#   2,
#   2,
#   2,
#   1,
#   1,
#   1,
#   4,
#   2,
#   2,
#   1.7724346693607036,
#   177,
#   'TACAyAAGACTGTACGTGCT',
#   'GGACAACGCCAATTGTAkAG',
#   55.34,
#   56.223),
#  ('orth3767_964-1531',
#   3,
#   2,
#   3,
#   2,
#   1,
#   2,
#   6,
#   4,
#   2,
#   1.7479133332816785,
#   173,
#   'AyAAGACTGTACGTGCTGCy',
#   'GACAACGCCAATTGTAkAGA',
#   56.096,
#   55.185),
#  ('orth3767_964-1531',
#   4,
#   2,
#   3,
#   2,
#   1,
#   2,
#   6,
#   4,
#   2,
#   1.7526168540623723,
#   175,
#   'AyAAGACTGTACGTGCTGCy',
#   'TGGACAACGCCAATTGTAkA',
#   56.096,
#   56.844),
#  ('orth3767_964-1531',
#   0,
#   2,
#   3,
#   2,
#   1,
#   2,
#   6,
#   4,
#   2,
#   1.7472606545652252,
#   174,
#   'AyAAGACTGTACGTGCTGCy',
#   'GGACAACGCCAATTGTAkAG',
#   56.096,
#   56.223),
#  ('orth3767_964-1531',
#   1,
#   2,
#   2,
#   1,
#   1,
#   1,
#   4,
#   2,
#   2,
#   1.7726864250365908,
#   178,
#   'GTACAyAAGACTGTACGTGC',
#   'GGACAACGCCAATTGTAkAG',
#   55.354,
#   56.223),
#  ('orth3787_1530-1751',
#   2,
#   2,
#   2,
#   0,
#   2,
#   2,
#   5,
#   1,
#   4,
#   0.9608460543998034,
#   165,
#   'AAACACCATCAACAGCTAGC',
#   'CTATTCAArCTrAGATTATGGCG',
#   56.33,
#   53.253),
#  ('orth3787_1530-1751',
#   4,
#   2,
#   2,
#   0,
#   2,
#   2,
#   5,
#   1,
#   4,
#   0.9615157966209492,
#   169,
#   'TTCCAAACACCATCAACAGC',
#   'CTATTCAArCTrAGATTATGGCG',
#   56.824,
#   53.253),
#  ('orth3787_1530-1751',
#   3,
#   2,
#   3,
#   1,
#   2,
#   2,
#   6,
#   2,
#   4,
#   0.9460357699771231,
#   162,
#   'CACCATCAACAGCTAGCTAy',
#   'CTATTCAArCTrAGATTATGGCG',
#   55.566,
#   53.253),
#  ('orth3787_1530-1751',
#   0,
#   2,
#   2,
#   0,
#   2,
#   2,
#   5,
#   1,
#   4,
#   0.9616892866810085,
#   167,
#   'CCAAACACCATCAACAGCTA',
#   'CTATTCAArCTrAGATTATGGCG',
#   55.949,
#   53.253),
#  ('orth3787_1530-1751',
#   1,
#   2,
#   2,
#   0,
#   2,
#   2,
#   5,
#   1,
#   4,
#   0.9612369519461476,
#   163,
#   'ACACCATCAACAGCTAGCTA',
#   'CTATTCAArCTrAGATTATGGCG',
#   56.255,
#   53.253),
#  ('orth3813_0-981',
#   3,
#   2,
#   4,
#   2,
#   2,
#   2,
#   10,
#   4,
#   6,
#   1.8185572782739357,
#   285,
#   'ATGGGTGTGCGwGGwCTCA',
#   'CCACAAGGATTdATrCGTTTGA',
#   56.083,
#   54.898),
#  ('orth3813_0-981',
#   2,
#   2,
#   4,
#   2,
#   2,
#   2,
#   8,
#   4,
#   4,
#   2.715545059157007,
#   379,
#   'TGGGTGTGCGwGGwCTCAC',
#   'GCCTCAAAmACrCAACGCAT',
#   57.124,
#   54.341),
#  ('orth3813_0-981',
#   1,
#   2,
#   4,
#   2,
#   2,
#   2,
#   8,
#   4,
#   4,
#   2.715545059157007,
#   379,
#   'ATGGGTGTGCGwGGwCTCAC',
#   'GCCTCAAAmACrCAACGCAT',
#   57.638,
#   54.341),
#  ('orth3813_0-981',
#   4,
#   2,
#   4,
#   2,
#   2,
#   2,
#   8,
#   4,
#   4,
#   2.720925371791569,
#   380,
#   'TGGGTGTGCGwGGwCTCA',
#   'GCCTCAAAmACrCAACGCAT',
#   55.455,
#   54.341),
#  ('orth3813_0-981',
#   0,
#   2,
#   4,
#   2,
#   2,
#   2,
#   8,
#   4,
#   4,
#   2.720925371791569,
#   380,
#   'ATGGGTGTGCGwGGwCTCA',
#   'GCCTCAAAmACrCAACGCAT',
#   56.083,
#   54.341),
#  ('orth3814_815-1335',
#   0,
#   0,
#   0,
#   0,
#   0,
#   0,
#   2,
#   1,
#   1,
#   0.08320702169681439,
#   164,
#   'TCTACTCGCTCGATTCGC',
#   'GTCCAACTTCTGCTGCAC',
#   56.693,
#   56.341),
#  ('orth3814_815-1335',
#   3,
#   0,
#   0,
#   0,
#   0,
#   0,
#   2,
#   1,
#   1,
#   0.08320702169681439,
#   164,
#   'GTCTACTCGCTCGATTCGC',
#   'GTCCAACTTCTGCTGCAC',
#   58.227,
#   56.341),
#  ('orth3814_815-1335',
#   1,
#   0,
#   0,
#   0,
#   0,
#   0,
#   2,
#   1,
#   1,
#   0.08353927096462044,
#   165,
#   'GTCTACTCGCTCGATTCG',
#   'GTCCAACTTCTGCTGCAC',
#   54.845,
#   56.341),
#  ('orth3814_815-1335',
#   2,
#   0,
#   0,
#   0,
#   0,
#   0,
#   2,
#   1,
#   1,
#   0.12082476897145217,
#   180,
#   'GATTCGCCAGACACCTTTC',
#   'CCATTGTGGGCTCATCCG',
#   56.328,
#   58.168),
#  ('orth3814_815-1335',
#   4,
#   0,
#   0,
#   0,
#   0,
#   0,
#   2,
#   1,
#   1,
#   0.08332071515895141,
#   169,
#   'TCTACTCGCTCGATTCGC',
#   'TAGGCGTCCAACTTCTGC',
#   56.693,
#   56.99),
#  ('orth3814_815-1335',
#   1,
#   1,
#   1,
#   0,
#   1,
#   1,
#   3,
#   1,
#   2,
#   0.08332071515895141,
#   169,
#   'TCTACTCGCTCGATTCGC',
#   'TrTAGGCGTCCAACTTCTGC',
#   56.693,
#   55.648),
#  ('orth3814_815-1335',
#   3,
#   1,
#   1,
#   0,
#   1,
#   1,
#   3,
#   1,
#   2,
#   0.08332071515895141,
#   169,
#   'GTCTACTCGCTCGATTCGC',
#   'TrTAGGCGTCCAACTTCTGC',
#   58.227,
#   55.648),
#  ('orth3814_815-1335',
#   0,
#   1,
#   1,
#   0,
#   1,
#   1,
#   3,
#   1,
#   2,
#   0.08323901289182604,
#   171,
#   'GATTCGCCAGACACCTTTC',
#   'GGCTCATCCGCCTTrTAGG',
#   56.328,
#   55.312),
#  ('orth3814_815-1335',
#   4,
#   1,
#   1,
#   0,
#   1,
#   1,
#   3,
#   1,
#   2,
#   0.08346326123889507,
#   170,
#   'ATTCGCCAGACACCTTTCA',
#   'GGCTCATCCGCCTTrTAGG',
#   56.97,
#   55.312),
#  ('orth3814_815-1335',
#   2,
#   1,
#   1,
#   0,
#   1,
#   1,
#   3,
#   1,
#   2,
#   0.08365545394437511,
#   170,
#   'GTCTACTCGCTCGATTCG',
#   'TrTAGGCGTCCAACTTCTGC',
#   54.845,
#   55.648),
#  ('orth3814_815-1335',
#   1,
#   2,
#   2,
#   0,
#   2,
#   2,
#   9,
#   1,
#   8,
#   1.126491153585852,
#   180,
#   'AGTATCCGATGGTGCGATAT',
#   'GGCAAnAGATCGTAkGCCAT',
#   55.987,
#   54.796),
#  ('orth3814_815-1335',
#   3,
#   2,
#   3,
#   1,
#   2,
#   2,
#   10,
#   2,
#   8,
#   1.115756299259843,
#   273,
#   'AGTGTCTrTATTCGCCAGCG',
#   'GGCAAnAGATCGTAkGCCAT',
#   55.84,
#   54.796),
#  ('orth3814_815-1335',
#   4,
#   2,
#   2,
#   0,
#   2,
#   2,
#   9,
#   1,
#   8,
#   1.127597645148742,
#   179,
#   'GTATCCGATGGTGCGATATC',
#   'GGCAAnAGATCGTAkGCCAT',
#   55.699,
#   54.796),
#  ('orth3814_815-1335',
#   0,
#   2,
#   3,
#   1,
#   2,
#   2,
#   10,
#   2,
#   8,
#   1.117062300340382,
#   268,
#   'CTrTATTCGCCAGCGTTTGC',
#   'GGCAAnAGATCGTAkGCCAT',
#   55.999,
#   54.796),
#  ('orth3814_815-1335',
#   2,
#   2,
#   3,
#   1,
#   2,
#   2,
#   10,
#   2,
#   8,
#   1.1158585314233267,
#   272,
#   'GTGTCTrTATTCGCCAGCGT',
#   'GGCAAnAGATCGTAkGCCAT',
#   56.132,
#   54.796),
#  ('orth3819_0-468',
#   0,
#   2,
#   4,
#   2,
#   2,
#   2,
#   8,
#   4,
#   4,
#   2.478304100403372,
#   207,
#   'TGGGTATGGTACArAArCGT',
#   'TGCACTTTGGTrCGrAAGTG',
#   53.998,
#   56.07),
#  ('orth3819_0-468',
#   1,
#   2,
#   4,
#   2,
#   2,
#   2,
#   8,
#   4,
#   4,
#   3.5074295445347663,
#   273,
#   'TGGGTATGGTACArAArCGT',
#   'CCAGCwGCACGyTCGGCTTC',
#   53.998,
#   56.26),
#  ('orth3819_0-468',
#   3,
#   2,
#   4,
#   2,
#   2,
#   2,
#   8,
#   4,
#   4,
#   3.5074295445347663,
#   273,
#   'ATGGGTATGGTACArAArCGT',
#   'CCAGCwGCACGyTCGGCTTC',
#   54.649,
#   56.26),
#  ('orth3819_0-468',
#   4,
#   2,
#   4,
#   2,
#   2,
#   2,
#   8,
#   4,
#   4,
#   2.4766969866646926,
#   206,
#   'TGGGTATGGTACArAArCGTA',
#   'TGCACTTTGGTrCGrAAGTG',
#   54.027,
#   56.07),
#  ('orth3819_0-468',
#   2,
#   2,
#   4,
#   2,
#   2,
#   2,
#   8,
#   4,
#   4,
#   2.478304100403372,
#   207,
#   'ATGGGTATGGTACArAArCGT',
#   'TGCACTTTGGTrCGrAAGTG',
#   54.649,
#   56.07),
#  ('orth3835_0-577',
#   2,
#   2,
#   4,
#   2,
#   2,
#   2,
#   12,
#   6,
#   6,
#   2.582952208737908,
#   338,
#   'yTGGACTATTACCAGCGhA',
#   'dATTTGyAAATGACCCCA',
#   54.898,
#   54.585),
#  ('orth3835_0-577',
#   4,
#   2,
#   3,
#   1,
#   2,
#   2,
#   9,
#   3,
#   6,
#   2.581718101855802,
#   337,
#   'TGGACTATTACCAGCGhAT',
#   'dATTTGyAAATGACCCCA',
#   53.525,
#   54.585),
#  ('orth3835_0-577',
#   0,
#   2,
#   4,
#   2,
#   2,
#   2,
#   12,
#   6,
#   6,
#   2.581718101855802,
#   337,
#   'yTGGACTATTACCAGCGhAT',
#   'dATTTGyAAATGACCCCA',
#   55.529,
#   54.585),
#  ('orth3835_0-577',
#   1,
#   2,
#   4,
#   2,
#   2,
#   2,
#   12,
#   6,
#   6,
#   2.5663853506655383,
#   336,
#   'TGGACTATTACCAGCGhATw',
#   'dATTTGyAAATGACCCCA',
#   54.672,
#   54.585),
#  ('orth3835_0-577',
#   3,
#   2,
#   4,
#   2,
#   2,
#   2,
#   12,
#   6,
#   6,
#   2.5669940502627067,
#   334,
#   'TGGACTATTACCAGCGhATwGT',
#   'dATTTGyAAATGACCCCA',
#   55.175,
#   54.585),
#  ('orth3862_768-1245',
#   3,
#   1,
#   2,
#   1,
#   1,
#   1,
#   7,
#   3,
#   4,
#   2.002529249892487,
#   160,
#   'GCTACACTTTGAChAGCATGTT',
#   'TCnGGTGGCACTTTGGTGAG',
#   55.633,
#   54.784),
#  ('orth3862_768-1245',
#   4,
#   1,
#   2,
#   1,
#   1,
#   1,
#   7,
#   3,
#   4,
#   2.003488164125018,
#   162,
#   'AGCTACACTTTGAChAGCATG',
#   'TCnGGTGGCACTTTGGTGAG',
#   54.571,
#   54.784),
#  ('orth3862_768-1245',
#   2,
#   1,
#   2,
#   1,
#   1,
#   1,
#   7,
#   3,
#   4,
#   2.003030113354553,
#   161,
#   'AGCTACACTTTGAChAGCATGT',
#   'TCnGGTGGCACTTTGGTGAG',
#   56.349,
#   54.784),
#  ('orth3862_768-1245',
#   1,
#   1,
#   2,
#   1,
#   1,
#   1,
#   7,
#   3,
#   4,
#   2.0045644631964716,
#   165,
#   'GGTAGCTACACTTTGAChAGC',
#   'TCnGGTGGCACTTTGGTGAG',
#   54.691,
#   54.784),
#  ('orth3862_768-1245',
#   0,
#   1,
#   2,
#   1,
#   1,
#   1,
#   7,
#   3,
#   4,
#   2.003030113354553,
#   161,
#   'GCTACACTTTGAChAGCATGT',
#   'TCnGGTGGCACTTTGGTGAG',
#   54.857,
#   54.784),
#  ('orth3862_768-1245',
#   3,
#   2,
#   3,
#   1,
#   2,
#   2,
#   11,
#   3,
#   8,
#   2.001286535430156,
#   161,
#   'GCTACACTTTGAChAGCATGTT',
#   'rTCnGGTGGCACTTTGGTGA',
#   55.633,
#   55.329),
#  ('orth3862_768-1245',
#   0,
#   2,
#   3,
#   1,
#   2,
#   2,
#   11,
#   3,
#   8,
#   2.001380992881026,
#   162,
#   'GCTACACTTTGAChAGCATGT',
#   'rTCnGGTGGCACTTTGGTGA',
#   54.857,
#   55.329),
#  ('orth3862_768-1245',
#   4,
#   2,
#   3,
#   1,
#   2,
#   2,
#   11,
#   3,
#   8,
#   2.0021090685032257,
#   163,
#   'AGCTACACTTTGAChAGCATG',
#   'rTCnGGTGGCACTTTGGTGA',
#   54.571,
#   55.329),
#  ('orth3862_768-1245',
#   2,
#   2,
#   3,
#   1,
#   2,
#   2,
#   11,
#   3,
#   8,
#   2.001380992881026,
#   162,
#   'AGCTACACTTTGAChAGCATGT',
#   'rTCnGGTGGCACTTTGGTGA',
#   56.349,
#   55.329),
#  ('orth3862_768-1245',
#   1,
#   2,
#   3,
#   1,
#   2,
#   2,
#   11,
#   3,
#   8,
#   2.0036567562377683,
#   166,
#   'GGTAGCTACACTTTGAChAGC',
#   'rTCnGGTGGCACTTTGGTGA',
#   54.691,
#   55.329),
#  ('orth3864_1755-2219',
#   0,
#   2,
#   3,
#   2,
#   1,
#   2,
#   6,
#   4,
#   2,
#   2.8377094804816174,
#   311,
#   'TGGAACAGGCTrTwTGTGATGT',
#   'ACCrATACCGGGTATCACGT',
#   53.68,
#   56.111),
#  ('orth3864_1755-2219',
#   1,
#   2,
#   4,
#   2,
#   2,
#   2,
#   8,
#   4,
#   4,
#   2.677008329727761,
#   306,
#   'TGGAACAGGCTrTwTGTGATGT',
#   'TACCGGGTATCACGTArAAy',
#   53.68,
#   55.194),
#  ('orth3864_1755-2219',
#   4,
#   2,
#   4,
#   2,
#   2,
#   2,
#   8,
#   4,
#   4,
#   2.082559499889943,
#   238,
#   'TGGAACAGGCTrTwTGTGATGT',
#   'GGrAArGCATACGCAATCGA',
#   53.68,
#   54.915),
#  ('orth3864_1755-2219',
#   3,
#   2,
#   3,
#   2,
#   1,
#   2,
#   6,
#   4,
#   2,
#   2.8377094804816174,
#   311,
#   'TGGAACAGGCTrTwTGTGATGT',
#   'TACCrATACCGGGTATCACGT',
#   53.68,
#   56.044),
#  ('orth3864_1755-2219',
#   2,
#   2,
#   3,
#   2,
#   1,
#   2,
#   6,
#   4,
#   2,
#   2.8361332311703973,
#   310,
#   'TGGAACAGGCTrTwTGTGATGT',
#   'ACCrATACCGGGTATCACGTA',
#   53.68,
#   56.044),
#  ('orth3893_476-1591',
#   1,
#   2,
#   3,
#   1,
#   2,
#   2,
#   10,
#   2,
#   8,
#   2.0234865773862505,
#   216,
#   'TTCGAACAGGGTTCAyTGCC',
#   'CCTTGGCnGCACArTCGGCA',
#   56.348,
#   56.285),
#  ('orth3893_476-1591',
#   3,
#   2,
#   4,
#   2,
#   2,
#   2,
#   14,
#   6,
#   8,
#   2.0263953561152,
#   217,
#   'hTTCGAACAGGGTTCAyTGC',
#   'CCTTGGCnGCACArTCGGCA',
#   55.552,
#   56.285),
#  ('orth3893_476-1591',
#   0,
#   2,
#   3,
#   1,
#   2,
#   2,
#   10,
#   2,
#   8,
#   2.0256532155820057,
#   217,
#   'TTCGAACAGGGTTCAyTGCC',
#   'ACCTTGGCnGCACArTCGGC',
#   56.348,
#   56.282),
#  ('orth3893_476-1591',
#   2,
#   2,
#   4,
#   2,
#   2,
#   2,
#   14,
#   6,
#   8,
#   2.0288739965875497,
#   218,
#   'hTTCGAACAGGGTTCAyTGC',
#   'ACCTTGGCnGCACArTCGGC',
#   55.552,
#   56.282),
#  ('orth3893_476-1591',
#   4,
#   2,
#   4,
#   2,
#   2,
#   2,
#   10,
#   4,
#   6,
#   1.9815790435911314,
#   191,
#   'AAGGGyATGTACGAyGTGGG',
#   'TGAACCCTGTTCGAAdAGkA',
#   55.175,
#   56.135),
#  ('orth3907_1874-2110',
#   0,
#   2,
#   4,
#   2,
#   2,
#   2,
#   12,
#   6,
#   6,
#   0.9516319315307467,
#   167,
#   'TCACAAGTrGTvTTCACCAATCCT',
#   'AsAGbGATTTTGTGTGCGCA',
#   54.423,
#   54.837),
#  ('orth3907_1874-2110',
#   2,
#   2,
#   4,
#   2,
#   2,
#   2,
#   12,
#   6,
#   6,
#   0.9526280491143915,
#   166,
#   'TCACAAGTrGTvTTCACCAATCCT',
#   'AsAGbGATTTTGTGTGCGCAT',
#   54.423,
#   55.432),
#  ('orth3907_1874-2110',
#   3,
#   2,
#   4,
#   2,
#   2,
#   2,
#   12,
#   6,
#   6,
#   0.9359010257433802,
#   164,
#   'TCACAAGTrGTvTTCACCAATCCT',
#   'bGATTTTGTGTGCGCATAw',
#   54.423,
#   55.392),
#  ('orth3907_1874-2110',
#   4,
#   2,
#   4,
#   2,
#   2,
#   2,
#   12,
#   6,
#   6,
#   0.9503609546315622,
#   168,
#   'TCACAAGTrGTvTTCACCAATCCT',
#   'GAAsAGbGATTTTGTGTGCGC',
#   54.423,
#   55.111),
#  ('orth3907_1874-2110',
#   1,
#   2,
#   4,
#   2,
#   2,
#   2,
#   12,
#   6,
#   6,
#   0.9516319315307467,
#   167,
#   'TCACAAGTrGTvTTCACCAATCCT',
#   'AAsAGbGATTTTGTGTGCGCA',
#   54.423,
#   55.653),
#  ('orth3915_1749-2005',
#   3,
#   1,
#   2,
#   1,
#   1,
#   1,
#   4,
#   2,
#   2,
#   0.3808631967414557,
#   163,
#   'AACACAATCGGyGATCGTCC',
#   'AAAAGTCTAAGyGCGCCAAG',
#   55.053,
#   53.42),
#  ('orth3915_1749-2005',
#   1,
#   1,
#   2,
#   1,
#   1,
#   1,
#   4,
#   2,
#   2,
#   0.38383011546886264,
#   160,
#   'ACAATCGGyGATCGTCCAGA',
#   'AAAAGTCTAAGyGCGCCAAG',
#   55.534,
#   53.42),
#  ...]

# %%
with open('combined_summory.csv', "w") as f:
    writer = csv.writer(f, delimiter=',', quotechar='"', quoting=csv.QUOTE_NONNUMERIC)
    writer.writerow(header)
    writer.writerows(data)
